# %% [markdown]
# # Run validation tests of HippoUnit on the Gómez González et al. 2011 model of hippocampal CA1 pyramidal cell
#
# The purpose of this notebook is to show how to run the validation tests of HippoUnit (https://github.com/KaliLab/hippounit) on the Gómez González et al. 2011 CA1 pyramidal cell model (ModelDB accession number: 144450).
#
# The tests shall take as input a standalone version of the model (a hoc file) that should not display any GUI, or contain any built in simulations and run-time modifications.
# __In this notebook the version of the model is tested that uses the n130 morphology__.
# The hoc file that is used in this notebook is available here:
# https://github.com/KaliLab/HippoUnit_demo/blob/master/published_models/CA1_Gomez_2011/experiment/junio/main_model_n130_morph.hoc
#
# Target experimental data that are used by the validation tests in this notebook are available here:
# https://github.com/KaliLab/HippoUnit_demo/tree/master/target_features

# %%
from __future__ import print_function

# %matplotlib inline

from hippounit.utils import ModelLoader
from hippounit import tests

from json2html import *
import pkg_resources
import json
import collections
import numpy
import IPython

# %% [markdown]
# ## Instantiating the model
#
# The ModelLoader class of HippoUnit is instantiated and the model, and simulation related parameters are set.

# %%
# path to mod files
mod_files_path = "../published_models/CA1_Gomez_2011/mechanism/"

#all the outputs will be saved here. It will be an argument to the test.
base_directory = '../published_models_validation_results/'

#Load cell model
model = ModelLoader(mod_files_path = mod_files_path )

# outputs will be saved in subfolders named like this:
model.name="Gomez_Gonzalez_2011_n130_morph"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "../published_models/CA1_Gomez_2011/experiment/junio/main_model_n130_morph.hoc"

# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = 'soma[0]'

# For the PSP Attenuation Test, and Back-propagating AP Test a section list containing the trunk sections is needed
model.TrunkSecList_name = 'apical_trunk_list'
# For the Oblique Integration Test a section list containing the oblique dendritic sections is needed
model.ObliqueSecList_name = 'oblique_dendrites'

#This will be argument to those tests, where dendritic locatins are selected according to distances. If not set, the end of the above given soma section will be used as reference point for distance determination
trunk_origin = ['soma[4]', 1] 

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -66
model.celsius = 34

# %% [markdown]
# ## Instantiating and running the tests of HippoUnit on the model
#
# At the end of each test, the user is provided with a textual summary of the score and the path to related output files generated by the tests.

# %% [markdown]
# ### Somatic Features Test - UCL data set
#
# It evaluates the model against various eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection of varying amplitudes. The experimental dataset used for validation is obtained from sharp electrode recordings in rats at UCL (Migliore et al. 2018  https://doi.org/10.1371/journal.pcbi.1006423).

# %%
# Load target data
with open('../target_features/feat_CA1_pyr_cACpyr_more_features.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

# %%
# Load stimuli file
ttype = "CA1_pyr_cACpyr"

stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_" + ttype + ".json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'UCL_data'

# Number of parallel processes
test.npool = 10
    
try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: -0.6 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.8 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.2 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: -0.2 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.0 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.4 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.6 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: -0.8 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: -0.4 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: -1.0 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/somaticfeat_UCL_data/Gomez_Gonzalez_2011_n130_morph/
# Number of features succesfully evaluated: 232/232
# Results are saved in the directory:  ../published_models_validation_results/results/somaticfeat_UCL_data/Gomez_Gonzalez_2011_n130_morph/
# === Model Gomez_Gonzalez_2011_n130_morph achieved score ZScore_avg = 4.19 on test 'Somatic features test'. ===

# %% [markdown]
# ### Somatic Features Test - JMakara data set
#
# It evaluates the model against various eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection of varying amplitudes. The experimental dataset used for validation is obtained from patch clamp recordings in rats by Judit Makara.

# %%
# Load target data
with open('../target_features/feat_rat_CA1_JMakara_more_features.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_rat_CA1_PC_JMakara.json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'JMakara_data'

# Number of parallel processes
test.npool = 10

try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: -0.15 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: -0.05 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: -0.2 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.05 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: -0.25 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: -0.1 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.2 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.25 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.1 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.15 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/somaticfeat_JMakara_data/Gomez_Gonzalez_2011_n130_morph/
# Number of features succesfully evaluated: 305/305
# Results are saved in the directory:  ../published_models_validation_results/results/somaticfeat_JMakara_data/Gomez_Gonzalez_2011_n130_morph/
# === Model Gomez_Gonzalez_2011_n130_morph achieved score ZScore_avg = 3.07 on test 'Somatic features test'. ===

# %% [markdown]
# ### PSP Attenuatuion Test
#
# The PSP Attenuation Test evaluates how much the post synaptic potential (using EPSC stimulus) attenuates from the main apical dendrite (different distances) to the soma. The soma/dendrite attenuation is compared to data from Magee & Cook 2000 (http://dx.doi.org/10.1038/78800).

# %%
# Load target data
with open("../target_features/feat_PSP_attenuation_target_data.json", 'r') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_attenuation_soma/dend_100_um</th><td>0.67037891837</td></tr><tr><th>std_attenuation_soma/dend_100_um</th><td>0.0745536001493</td></tr><tr><th>mean_attenuation_soma/dend_200_um</th><td>0.485024302539</td></tr><tr><th>std_attenuation_soma/dend_200_um</th><td>0.108372269307</td></tr><tr><th>mean_attenuation_soma/dend_300_um</th><td>0.282118043034</td></tr><tr><th>std_attenuation_soma/dend_300_um</th><td>0.0482703550105</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/PSP_attenuation_stim/stim_PSP_attenuation_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate test class 
test = tests.PSPAttenuationTest(config=config, observation=observation, num_of_dend_locations = 15, force_run=False, show_plot=True, save_all = True, base_directory=base_directory, trunk_origin=trunk_origin)
            
# Number of parallel processes
test.npool = 10

try: 
    # Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('trunk[15]', 0.30000000000000004): 293.45596506009764, ('trunk[3]', 0.8999999999999999): 63.573903285949655, ('trunk[10]', 0.1): 147.6685980392587, ('trunk[14]', 0.8999999999999999): 266.6825654438465, ('trunk[10]', 0.5): 174.2636794171762, ('trunk[12]', 0.8999999999999999): 225.06232988530405, ('trunk[13]', 0.1): 229.38043738343572, ('trunk[5]', 0.7): 90.18574619507683, ('trunk[3]', 0.7): 54.078431486947515, ('trunk[15]', 0.7): 326.81800988536975, ('trunk[10]', 0.8999999999999999): 200.8587607950937, ('trunk[13]', 0.7): 243.73732677326012, ('trunk[15]', 0.1): 276.7749426474616, ('trunk[9]', 0.30000000000000004): 134.4879766090421, ('trunk[10]', 0.30000000000000004): 160.96613872821746}
# input at: trunk[15](0.30000000000000004) with weight: 0.0
# input at: trunk[15](0.1) with weight: 0.0
# input at: trunk[5](0.7) with weight: 0.0
# input at: trunk[10](0.5) with weight: 0.0
# input at: trunk[10](0.30000000000000004) with weight: 0.0
# input at: trunk[13](0.1) with weight: 0.0
# input at: trunk[10](0.1) with weight: 0.0
# input at: trunk[14](0.8999999999999999) with weight: 0.0
# input at: trunk[15](0.7) with weight: 0.0
# input at: trunk[10](0.8999999999999999) with weight: 0.0
# input at: trunk[3](0.8999999999999999) with weight: 0.0
# input at: trunk[3](0.7) with weight: 0.0
# input at: trunk[13](0.7) with weight: 0.0
# input at: trunk[12](0.8999999999999999) with weight: 0.0
# input at: trunk[9](0.30000000000000004) with weight: 0.0
# input at: trunk[10](0.1) with weight: 0.0004541345484790677
# input at: trunk[15](0.7) with weight: 0.00045419276157660773
# input at: trunk[3](0.8999999999999999) with weight: 0.0004541213041746197
# input at: trunk[14](0.8999999999999999) with weight: 0.00045417248500033934
# input at: trunk[12](0.8999999999999999) with weight: 0.00045415878478399286
# input at: trunk[13](0.7) with weight: 0.00045416509674817
# input at: trunk[3](0.7) with weight: 0.00045412038124131914
# input at: trunk[10](0.30000000000000004) with weight: 0.00045413393355095086
# input at: trunk[5](0.7) with weight: 0.0004541260172910378
# input at: trunk[15](0.1) with weight: 0.00045417568255098065
# input at: trunk[10](0.8999999999999999) with weight: 0.00045414978660360283
# input at: trunk[13](0.1) with weight: 0.0004541602832658749
# input at: trunk[15](0.30000000000000004) with weight: 0.000454181156959241
# input at: trunk[9](0.30000000000000004) with weight: 0.0004541350761662367
# input at: trunk[10](0.5) with weight: 0.00045413921161839175
# The figures are saved in the directory:  ../published_models_validation_results/figs/PSP_attenuation/Gomez_Gonzalez_2011_n130_morph/
# === Model Gomez_Gonzalez_2011_n130_morph achieved score ZScore_avg = 1.74 on test 'PSP attenuation test'. ===

# %% [markdown]
# ### Back-Propagating AP Test
#
# The Back-Propagating AP Test evaluates the mode and efficacy of back-propagating action potentials on the apical trunk in locations of different distances from the soma. The amplitude of the first and last AP of around 15 Hz train is compared to experimental data from Golding et al. 2001 (https://doi.org/10.1152/jn.2001.86.6.2998).

# %%
# Load target data
with open('../target_features/feat_backpropagating_AP_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_AP1_amp_at_50um</th><td>66.6474010216 mV</td></tr><tr><th>std_AP1_amp_at_50um</th><td>7.6800611053 mV</td></tr><tr><th>mean_AP1_amp_at_150um</th><td>61.6405452338 mV</td></tr><tr><th>std_AP1_amp_at_150um</th><td>8.84061901299 mV</td></tr><tr><th>mean_AP1_amp_at_250um</th><td>57.1478276286 mV</td></tr><tr><th>std_AP1_amp_at_250um</th><td>6.74288151869 mV</td></tr><tr><th>mean_AP1_amp_strong_propagating_at_350um</th><td>52.5065653152 mV</td></tr><tr><th>std_AP1_amp_strong_propagating_at_350um</th><td>5.82443856294 mV</td></tr><tr><th>mean_AP1_amp_weak_propagating_at_350um</th><td>18.7832282514 mV</td></tr><tr><th>std_AP1_amp_weak_propagating_at_350um</th><td>1.87203344953 mV</td></tr><tr><th>mean_APlast_amp_at_50um</th><td>56.0027067193 mV</td></tr><tr><th>std_APlast_amp_at_50um</th><td>6.66451614848 mV</td></tr><tr><th>mean_APlast_amp_at_150um</th><td>41.6724147741 mV</td></tr><tr><th>std_APlast_amp_at_150um</th><td>7.62175409041 mV</td></tr><tr><th>mean_APlast_amp_at_250um</th><td>21.1507839635 mV</td></tr><tr><th>std_APlast_amp_at_250um</th><td>2.39551093081 mV</td></tr><tr><th>mean_APlast_amp_at_350um</th><td>9.81008709754 mV</td></tr><tr><th>std_APlast_amp_at_350um</th><td>3.67378280696 mV</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/bAP_stim/stim_bAP_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate the test class
test = tests.BackpropagatingAPTest(config=config, observation=observation, force_run=False, force_run_FindCurrentStim=False, show_plot=True, save_all=True, base_directory=base_directory, trunk_origin=trunk_origin)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('trunk[4]', 0.1): 68.53187113474286, ('trunk[13]', 0.7): 243.73732677326012, ('trunk[14]', 0.30000000000000004): 256.1713694600637, ('trunk[8]', 0.8999999999999999): 130.44729415315294, ('trunk[4]', 0.5): 69.37279893191143, ('trunk[14]', 0.1): 252.66763746546945, ('trunk[14]', 0.8999999999999999): 266.6825654438465, ('trunk[9]', 0.1): 132.6217334416886, ('trunk[3]', 0.7): 54.078431486947515, ('trunk[10]', 0.30000000000000004): 160.96613872821746, ('trunk[3]', 0.8999999999999999): 63.573903285949655, ('trunk[9]', 0.5): 136.3542197763956, ('trunk[4]', 0.30000000000000004): 68.95233503332715, ('trunk[9]', 0.7): 138.2204629437491, ('trunk[14]', 0.7): 263.17883344925224, ('trunk[3]', 0.30000000000000004): 35.087487888943244, ('trunk[13]', 0.8999999999999999): 248.52295656986826, ('trunk[9]', 0.8999999999999999): 140.0867061111026, ('trunk[13]', 0.5): 238.951696976652, ('trunk[14]', 0.5): 259.675101454658, ('trunk[15]', 0.8999999999999999): 343.49903229800583, ('trunk[3]', 0.5): 44.582959687945376, ('trunk[13]', 0.30000000000000004): 234.16606718004385, ('trunk[4]', 0.7): 69.7932628304957, ('trunk[9]', 0.30000000000000004): 134.4879766090421, ('trunk[10]', 0.1): 147.6685980392587}
# Finding appropriate current step amplitude...
# - running amplitude: 0.1 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.0 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.30000000000000004 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.6000000000000001 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.9 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.7000000000000001 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.4 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.2 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.8 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.5 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.0 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.13999999999999999 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.16999999999999998 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.14999999999999997 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.15999999999999998 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.15999999999999998 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/backpropagating_AP/Gomez_Gonzalez_2011_n130_morph/
# This is a rather STRONG propagating model
# === Model Gomez_Gonzalez_2011_n130_morph achieved score Z_score_avg_STRONG_propagating = 3.82 on test 'Back-propagating action potential test'. ===

# %% [markdown]
# ### Depolarization-block Test
#
# The Depolarization Block Test aims to determine whether the model enters depolarization block to prolonged, high intensity somatic current stimulus. It compares the current intensity to which the model fires the maximum number of action potentials, the current intensity before the model enters depolarization block (the two should be equal) and the equilibrium potential during depolarization block to the experimental data of Bianchi et al. 2012 (http://dx.doi.org/10.1007/s10827-012-0383-y).

# %%
# Load target data
with open('../target_features/depol_block_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_Ith</th><td>0.6 nA</td></tr><tr><th>Ith_std</th><td>0.3 nA</td></tr><tr><th>mean_Veq</th><td>-40.1 mV</td></tr><tr><th>Veq_std</th><td>3.4 mV</td></tr></table>

# %%
# Instantiate the test class

test = tests.DepolarizationBlockTest(observation=observation, force_run=False, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: 0.25 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.30000000000000004 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.35000000000000003 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.15000000000000002 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.0 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.45 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.2 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.4 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.1 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.05 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.5 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.55 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.6000000000000001 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.65 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.7000000000000001 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.75 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.8 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.8500000000000001 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.9 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 0.9500000000000001 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.0 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.05 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.1 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.1500000000000001 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.2000000000000002 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.25 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.3 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.35 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.4000000000000001 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.4500000000000002 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.5 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.55 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# - running amplitude: 1.6 on model: Gomez_Gonzalez_2011_n130_morph at: soma[0](0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/depol_block/Gomez_Gonzalez_2011_n130_morph/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.55 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  ../published_models_validation_results/results/depol_block/Gomez_Gonzalez_2011_n130_morph/
# The model did not enter depolarization block.
# === Model Gomez_Gonzalez_2011_n130_morph achieved score ZScore_avg+penalty = 100.00 on test 'Depolarization block test'. ===

# %% [markdown]
# ### Oblique Integration Test
#
# Tests signal integration in oblique dendrites for increasing number of synchronous and asynchronous synaptic inputs. The experimental data is obtained from Losonczy and Magee 2006 (https://doi.org/10.1016/j.neuron.2006.03.016).

# %%
# Load target data
with open('../target_features/oblique_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_threshold</th><td>3.4 mV</td></tr><tr><th>threshold_sem</th><td>0.2 mV</td></tr><tr><th>exp_n</th><td>92</td></tr><tr><th>mean_prox_threshold</th><td>4.5 mV</td></tr><tr><th>prox_threshold_sem</th><td>0.5 mV</td></tr><tr><th>prox_n</th><td>33</td></tr><tr><th>mean_dist_threshold</th><td>2.6 mV</td></tr><tr><th>dist_threshold_sem</th><td>0.2 mV</td></tr><tr><th>dist_n</th><td>44</td></tr><tr><th>mean_nonlin_at_th</th><td>142</td></tr><tr><th>nonlin_at_th_sem</th><td>9</td></tr><tr><th>mean_nonlin_suprath</th><td>129.0</td></tr><tr><th>nonlin_suprath_sem</th><td>6.0</td></tr><tr><th>mean_peak_deriv</th><td>2.6 V/s</td></tr><tr><th>peak_deriv_sem</th><td>0.4 V/s</td></tr><tr><th>mean_amp_at_th</th><td>4.828 mV</td></tr><tr><th>amp_at_th_sem</th><td>0.28 mV</td></tr><tr><th>mean_time_to_peak</th><td>13.5 ms</td></tr><tr><th>time_to_peak_sem</th><td>0.2 ms</td></tr><tr><th>mean_async_nonlin</th><td>104.0</td></tr><tr><th>async_nonlin_sem</th><td>8.0</td></tr><tr><th>async_n</th><td>23</td></tr></table>

# %%
#setting synapse parameters

# If model.AMPA_name and/or model.NMDA_name is set here, the model's own receptor models (mod files) are used. 
# If these are not set, HippoUnit's default synapse model is used. (AMPA: NEURON's Exp2Syn, NMDA: https://github.com/KaliLab/hippounit/blob/master/hippounit/tests/default_NMDAr/NMDA_CA1_pyr_SC.mod) 

model.NMDA_name = 'NMDA'
model.AMPA_name = 'GLU'
model.AMPA_NMDA_ratio = 1/0.396

# Instantiate the test class
test = tests.ObliqueIntegrationTest(observation = observation, save_all = True, force_run_synapse=False, force_run_bin_search=False, show_plot = True, base_directory = base_directory, trunk_origin=trunk_origin)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# Dendrites and locations to be tested:  [['apical_dendrite[154]', 0.125, 'prox'], ['apical_dendrite[154]', 0.375, 'dist'], ['apical_dendrite[174]', 0.16666666666666666, 'prox'], ['apical_dendrite[174]', 0.5, 'dist'], ['apical_dendrite[175]', 0.16666666666666666, 'prox'], ['apical_dendrite[175]', 0.5, 'dist'], ['apical_dendrite[176]', 0.16666666666666666, 'prox'], ['apical_dendrite[176]', 0.5, 'dist'], ['apical_dendrite[178]', 0.5, 'prox'], ['apical_dendrite[178]', 0.9, 'dist'], ['apical_dendrite[179]', 0.16666666666666666, 'prox'], ['apical_dendrite[179]', 0.5, 'dist'], ['apical_dendrite[188]', 0.5, 'prox'], ['apical_dendrite[188]', 0.9, 'dist'], ['apical_dendrite[189]', 0.16666666666666666, 'prox'], ['apical_dendrite[189]', 0.5, 'dist'], ['apical_dendrite[190]', 0.25, 'prox'], ['apical_dendrite[190]', 0.75, 'dist'], ['apical_dendrite[232]', 0.25, 'prox'], ['apical_dendrite[232]', 0.75, 'dist'], ['apical_dendrite[233]', 0.25, 'prox'], ['apical_dendrite[233]', 0.75, 'dist'], ['apical_dendrite[234]', 0.5, 'prox'], ['apical_dendrite[234]', 0.9, 'dist'], ['apical_dendrite[236]', 0.25, 'prox'], ['apical_dendrite[236]', 0.75, 'dist'], ['apical_dendrite[237]', 0.25, 'prox'], ['apical_dendrite[237]', 0.75, 'dist']]
# Adjusting synaptic weights on all the locations ...
# The dendritic spike at dendrite apical_dendrite[154](0.125) generated somatic AP - this location is not used in the test
# - number of inputs: 5 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 7 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 8 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 0 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 1 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 3 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 2 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 9 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 4 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 6 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 10 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 0 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 1 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 2 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 3 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 4 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 5 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 6 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 7 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 8 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 9 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 10 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 0 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 1 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 2 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 3 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 4 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 5 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 6 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 7 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 8 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 9 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 10 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 0 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 0 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 0 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 0 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 1 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 2 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 3 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 4 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 5 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 6 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 7 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 8 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 9 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 10 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 0 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 0 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 0 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 9 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 8 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 4 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 7 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 1 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 6 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 2 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 5 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 10 dendrite: apical_dendrite[154] xloc: 0.375
# - number of inputs: 0 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[174] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[174] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[175] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[175] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[176] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[176] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[178] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 1 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 2 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 3 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 4 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 5 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 6 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 7 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 8 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 9 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 10 dendrite: apical_dendrite[178] xloc: 0.9
# - number of inputs: 0 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[179] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[179] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[188] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 1 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 2 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 3 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 4 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 5 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 6 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 7 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 8 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 9 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 10 dendrite: apical_dendrite[188] xloc: 0.9
# - number of inputs: 0 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[189] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[189] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[190] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[190] xloc: 0.75
# - number of inputs: 0 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[232] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[232] xloc: 0.75
# - number of inputs: 0 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[233] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[233] xloc: 0.75
# - number of inputs: 0 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[234] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 1 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 2 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 3 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 4 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 5 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 6 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 7 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 8 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 9 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 10 dendrite: apical_dendrite[234] xloc: 0.9
# - number of inputs: 0 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[236] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[236] xloc: 0.75
# - number of inputs: 0 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[237] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[237] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[237] xloc: 0.75
# The figures are saved in the directory:  ../published_models_validation_results/figs/oblique_integration/Gomez_Gonzalez_2011_n130_morph/
# Results are saved in the directory:  ../published_models_validation_results/results/oblique_integration/Gomez_Gonzalez_2011_n130_morph/
# === Model Gomez_Gonzalez_2011_n130_morph achieved score ZScore_avg = 0.62 on test 'Oblique integration test'. ===

# %%
# %load_ext watermark

# %%
# %watermark -v -m -p sciunit,efel,numpy,quantities,scipy,matplotlib,neuron
# Out:
# CPython 3.5.2
# IPython 5.6.0
#
# sciunit 0.2.1.1
# efel 3.0.58
# numpy 1.16.4
# quantities 0.12.1
# scipy 1.3.0
# matplotlib 3.0.3
# neuron 7.6.2
#
# compiler   : GCC 5.4.0 20160609
# system     : Linux
# release    : 4.15.0-74-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 56
# interpreter: 64bit
