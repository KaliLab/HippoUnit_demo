# %%
% matplotlib inline

from hippounit.utils import ModelLoader
from hippounit import tests

from json2html import *
import pkg_resources
import json
import collections
import numpy
import IPython
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
# path to mod files
mod_files_path = "/home/saray/published_models/Katz_et_al_2009_2stageintegration_code/"

#all the outputs will be saved here. It will be an argument to the test.
base_directory = '/mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/'

#Load cell model
model = ModelLoader(mod_files_path = mod_files_path )

# outputs will be saved in subfolders named like this:
model.name="Katz_et_al_2009"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "/home/saray/published_models/Katz_et_al_2009_2stageintegration_code/main_model.hoc"

# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = 'somaA'

# For the PSP Attenuation Test, and Back-propagating AP Test a section list containing the trunk sections is needed
model.TrunkSecList_name = 'primary_apical_list'
# For the Oblique Integration Test a section list containing the oblique dendritic sections is needed
model.ObliqueSecList_name = 'oblique_dendrites'


model.v_init = -70
model.celsius = 35

# %% [markdown]
# ### Somatic Features Test - UCL data set

# %%
# Load target data
with open('/home/saray/target_features/feat_CA1_pyr_cACpyr_more_features.json') as f:
    config_pyr = json.load(f, object_pairs_hook=collections.OrderedDict)
    
observation = config_pyr

# %%
# Load stimuli file
ttype = "CA1_pyr_cACpyr"

stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_" + ttype + ".json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'UCL_data'

# Number of parallel processes
test.npool = 10
    
try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# - running amplitude: -1.0 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: -0.8 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: -0.6 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: -0.4 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: -0.2 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.2 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.6 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.8 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.4 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.0 on model: Katz_et_al_2009 at: somaA(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/somaticfeat_UCL_data/Katz_et_al_2009/
# Number of features succesfully evaluated: 232/232
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/results/somaticfeat_UCL_data/Katz_et_al_2009/
# === Model Katz_et_al_2009 achieved score ZScore_avg = 3.95 on test 'Somatic features test'. ===

# %% [markdown]
# ### Somatic Features Test - JMakara data set

# %%
# Load target data
with open('/home/saray/target_features/feat_rat_CA1_JMakara_more_features.json') as f:
    config_pyr = json.load(f, object_pairs_hook=collections.OrderedDict)
    
observation = config_pyr

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_rat_CA1_PC_JMakara.json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'JMakara_data'

# Number of parallel processes
test.npool = 10

try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# - running amplitude: -0.25 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: -0.2 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: -0.15 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: -0.05 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.05 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: -0.1 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.1 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.15 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.2 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.25 on model: Katz_et_al_2009 at: somaA(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/somaticfeat_JMakara_data/Katz_et_al_2009/
# Features excluded (due to invalid values): initburst_sahp.Step0.25, initburst_sahp_ssse.Step0.25, initburst_sahp_vb.Step0.25
# Number of features succesfully evaluated: 302/305
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/results/somaticfeat_JMakara_data/Katz_et_al_2009/
# /usr/local/lib/python2.7/dist-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# === Model Katz_et_al_2009 achieved score ZScore_avg = 4.61 on test 'Somatic features test'. ===

# %% [markdown]
# ### PSP Attenuatuion Test

# %%
# Load target data
with open("/home/saray/target_features/feat_PSP_attenuation_target_data.json", 'r') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_attenuation_soma/dend_100_um</th><td>0.67037891837</td></tr><tr><th>std_attenuation_soma/dend_100_um</th><td>0.0745536001493</td></tr><tr><th>mean_attenuation_soma/dend_200_um</th><td>0.485024302539</td></tr><tr><th>std_attenuation_soma/dend_200_um</th><td>0.108372269307</td></tr><tr><th>mean_attenuation_soma/dend_300_um</th><td>0.282118043034</td></tr><tr><th>std_attenuation_soma/dend_300_um</th><td>0.0482703550105</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/PSP_attenuation_stim/stim_PSP_attenuation_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate test class 
test = tests.PSPAttenuationTest(config=config, observation=observation, num_of_dend_locations = 15, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)
            
# Number of parallel processes
test.npool = 10

try: 
    # Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('dendA5_011111111111', 0.5): 239.79096715191383, ('dendA5_01111111', 0.16666666666666666): 191.3337915422833, ('dendA5_01', 0.5): 56.19888262225582, ('dendA5_0111111111', 0.30000000000000004): 209.08951965594616, ('dendA5_0111111111111', 0.9285714285714284): 278.8585387217133, ('dendA5_01111111111111', 0.8636363636363638): 322.72005649527625, ('dendA5_01111111111111', 0.9545454545454547): 327.083638729302, ('dendA5_0111111', 0.7857142857142856): 182.82650065736274, ('dendA5_0111111111', 0.7): 217.31184133531076, ('dendA5_01', 0.7727272727272728): 71.86747110540054, ('dendA5_011111111111111', 0.8333333333333333): 337.0317515174673, ('dendA5_01111111', 0.5): 193.880682041602, ('dendA5_0111', 0.5): 109.82321709039796, ('dendA5_0111111', 0.9285714285714284): 187.64906441420356, ('dendA5_011111111', 0.5): 200.31189809350136}
# input at: dendA5_01111111111111(0.954545454545) with weight: 0.0
# input at: dendA5_01(0.5) with weight: 0.0
# input at: dendA5_0111(0.5) with weight: 0.0
# input at: dendA5_0111111111(0.3) with weight: 0.0
# input at: dendA5_01111111(0.166666666667) with weight: 0.0
# input at: dendA5_0111111111111(0.928571428571) with weight: 0.0
# input at: dendA5_011111111111111(0.833333333333) with weight: 0.0
# input at: dendA5_0111111(0.785714285714) with weight: 0.0
# input at: dendA5_01111111111111(0.863636363636) with weight: 0.0
# input at: dendA5_0111111(0.928571428571) with weight: 0.0
# input at: dendA5_01111111(0.5) with weight: 0.0
# input at: dendA5_011111111111(0.5) with weight: 0.0
# input at: dendA5_011111111(0.5) with weight: 0.0
# input at: dendA5_0111111111(0.7) with weight: 0.0
# input at: dendA5_01(0.772727272727) with weight: 0.0
# input at: dendA5_011111111(0.5) with weight: 0.0004212181945836454
# input at: dendA5_0111111(0.785714285714) with weight: 0.0004214909616030644
# input at: dendA5_01111111111111(0.863636363636) with weight: 0.0004198411702289405
# input at: dendA5_01(0.772727272727) with weight: 0.000423232235714769
# input at: dendA5_0111111111111(0.928571428571) with weight: 0.000420341648193292
# input at: dendA5_0111111111(0.7) with weight: 0.000421036008471113
# input at: dendA5_0111(0.5) with weight: 0.0004227967407129742
# input at: dendA5_01111111111111(0.954545454545) with weight: 0.00041980449947142984
# input at: dendA5_011111111111111(0.833333333333) with weight: 0.00041970917465318936
# input at: dendA5_01111111(0.166666666667) with weight: 0.0004213329497273262
# input at: dendA5_011111111111(0.5) with weight: 0.00042078061936093455
# input at: dendA5_01111111(0.5) with weight: 0.0004212969622186114
# input at: dendA5_0111111111(0.3) with weight: 0.0004211230586975956
# input at: dendA5_0111111(0.928571428571) with weight: 0.0004213975376477991
# input at: dendA5_01(0.5) with weight: 0.00042340583144195724
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/PSP_attenuation/Katz_et_al_2009/
# === Model Katz_et_al_2009 achieved score ZScore_avg = 0.91 on test 'PSP attenuation test'. ===

# %% [markdown]
# ### Back-Propagating AP Test

# %%
# Load target data
with open('/home/saray/target_features/feat_backpropagating_AP_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

#observation = config['features']
IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_AP1_amp_at_50um</th><td>66.6474010216 mV</td></tr><tr><th>std_AP1_amp_at_50um</th><td>7.6800611053 mV</td></tr><tr><th>mean_AP1_amp_at_150um</th><td>61.6405452338 mV</td></tr><tr><th>std_AP1_amp_at_150um</th><td>8.84061901299 mV</td></tr><tr><th>mean_AP1_amp_at_250um</th><td>57.1478276286 mV</td></tr><tr><th>std_AP1_amp_at_250um</th><td>6.74288151869 mV</td></tr><tr><th>mean_AP1_amp_strong_propagating_at_350um</th><td>52.5065653152 mV</td></tr><tr><th>std_AP1_amp_strong_propagating_at_350um</th><td>5.82443856294 mV</td></tr><tr><th>mean_AP1_amp_weak_propagating_at_350um</th><td>18.7832282514 mV</td></tr><tr><th>std_AP1_amp_weak_propagating_at_350um</th><td>1.87203344953 mV</td></tr><tr><th>mean_APlast_amp_at_50um</th><td>56.0027067193 mV</td></tr><tr><th>std_APlast_amp_at_50um</th><td>6.66451614848 mV</td></tr><tr><th>mean_APlast_amp_at_150um</th><td>41.6724147741 mV</td></tr><tr><th>std_APlast_amp_at_150um</th><td>7.62175409041 mV</td></tr><tr><th>mean_APlast_amp_at_250um</th><td>21.1507839635 mV</td></tr><tr><th>std_APlast_amp_at_250um</th><td>2.39551093081 mV</td></tr><tr><th>mean_APlast_amp_at_350um</th><td>9.81008709754 mV</td></tr><tr><th>std_APlast_amp_at_350um</th><td>3.67378280696 mV</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/bAP_stim/stim_bAP_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate the test class
test = tests.BackpropagatingAPTest(config=config, observation=observation, force_run=False, force_run_FindCurrentStim=False, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('dendA5_011111', 0.5): 150.49165189616144, ('dendA5_01', 0.045454545454545456): 30.084568483681313, ('dendA5_0111111111111111', 0.20588235294117646): 354.715732316079, ('dendA5_011111111111111', 0.8333333333333333): 337.0317515174673, ('dendA5_0111111111111111', 0.3823529411764706): 368.5420607141201, ('dendA5_01', 0.40909090909090906): 50.976019794540925, ('dendA5_011111', 0.16666666666666666): 146.61781983044364, ('dendA5_01', 0.22727272727272727): 40.53029413911112, ('dendA5_01', 0.5909090909090909): 61.42174544997073, ('dendA5_0111111111111111', 0.2647058823529412): 359.3245084487594, ('dendA5_01111', 0.7857142857142856): 138.0089804558018, ('dendA5_0111111', 0.21428571428571427): 163.53624562999937, ('dendA5_011111', 0.8333333333333333): 154.36548396187922, ('dendA5_011111111111', 0.5): 239.79096715191383, ('dendA5_01111', 0.9285714285714284): 142.45692935032375, ('dendA5_0111111111111', 0.3571428571428571): 259.5986463191625, ('dendA5_01', 0.6818181818181819): 66.64460827768563, ('dendA5_0111111111111111', 0.14705882352941174): 350.10695618339867, ('dendA5_011111111111111', 0.5): 333.9252228490063, ('dendA5_011111111111111', 0.16666666666666666): 330.8186941805453, ('dendA5_0111111111111', 0.49999999999999994): 264.4136194198002, ('dendA5_0111111111111', 0.07142857142857142): 249.96870011788712, ('dendA5_01', 0.13636363636363635): 35.307431311396215, ('dendA5_01', 0.5): 56.19888262225582, ('dendA5_0111111111111111', 0.029411764705882353): 340.88940391803794, ('dendA5_0111111', 0.07142857142857142): 158.71368187315855, ('dendA5_0111111111111111', 0.3235294117647059): 363.93328458143975, ('dendA5_0111111111111', 0.21428571428571427): 254.78367321852483, ('dendA5_01111', 0.6428571428571428): 133.56103156127986, ('dendA5_011111111111', 0.8333333333333333): 244.9711314290168, ('dendA5_0111111', 0.3571428571428571): 168.35880938684022, ('dendA5_011111111111', 0.16666666666666666): 234.61080287481082, ('dendA5_0111111111111', 0.6428571428571428): 269.2285925204379, ('dendA5_01', 0.3181818181818182): 45.75315696682602, ('dendA5_0111111111111111', 0.08823529411764705): 345.4981800507183, ('dendA5_01111111111', 0.8333333333333333): 230.5970310460218}
# Finding appropriate current step amplitude...
# - running amplitude: 0.0 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.1 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.2 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.30000000000000004 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.4 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.5 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.6000000000000001 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.8 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.7000000000000001 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.9 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.0 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.04 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.07 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.05 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.06 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.045 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.055 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.065 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.0475 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.0725 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.0675 on model: Katz_et_al_2009 at: somaA(0.5)
# WARNING: No current amplitude value has been found to which the model's firing frequency is between 10 and 20 Hz. The simulation is done using the current amplitude value to which the models fires at a frequency nearest to 15 Hz, but not 0 Hz. Current step amplitude: 0.0675nA, frequency: [40]Hz
#
# - running amplitude: 0.0675 on model: Katz_et_al_2009 at: somaA(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/backpropagating_AP/Katz_et_al_2009/
# This is a rather STRONG propagating model
# === Model Katz_et_al_2009 achieved score Z_score_avg_STRONG_propagating = 4.58 on test 'Back-propagating action potential test'. ===

# %% [markdown]
# ### Depolarization-block Test

# %%
# Load target data
with open('/home/saray/target_features/depol_block_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

#observation = config['features']
IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_Ith</th><td>0.6 nA</td></tr><tr><th>Ith_std</th><td>0.3 nA</td></tr><tr><th>mean_Veq</th><td>-40.1 mV</td></tr><tr><th>Veq_std</th><td>3.4 mV</td></tr></table>

# %%
# Instantiate the test class

test = tests.DepolarizationBlockTest(observation=observation, force_run=False, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# - running amplitude: 0.0 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.05 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.1 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.15000000000000002 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.2 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.25 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.30000000000000004 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.35000000000000003 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.4 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.45 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.5 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.55 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.6000000000000001 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.65 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.7000000000000001 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.75 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.8 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.8500000000000001 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.9 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 0.9500000000000001 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.0 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.05 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.1 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.1500000000000001 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.2000000000000002 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.25 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.3 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.35 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.4000000000000001 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.4500000000000002 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.5 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.55 on model: Katz_et_al_2009 at: somaA(0.5)
# - running amplitude: 1.6 on model: Katz_et_al_2009 at: somaA(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/depol_block/Katz_et_al_2009/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 0.9 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 0.9 nA
# Veq (the equilibrium value during the depolarization block): -28.99074528137448 mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/results/depol_block/Katz_et_al_2009/
# === Model Katz_et_al_2009 achieved score ZScore_avg+penalty = 1.76 on test 'Depolarization block test'. ===

# %% [markdown]
# ### Oblique Integration Test

# %%
# Load target data
with open('/home/saray/target_features/oblique_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_threshold</th><td>3.4 mV</td></tr><tr><th>threshold_sem</th><td>0.2 mV</td></tr><tr><th>exp_n</th><td>92</td></tr><tr><th>mean_prox_threshold</th><td>4.5 mV</td></tr><tr><th>prox_threshold_sem</th><td>0.5 mV</td></tr><tr><th>prox_n</th><td>33</td></tr><tr><th>mean_dist_threshold</th><td>2.6 mV</td></tr><tr><th>dist_threshold_sem</th><td>0.2 mV</td></tr><tr><th>dist_n</th><td>44</td></tr><tr><th>mean_nonlin_at_th</th><td>142</td></tr><tr><th>nonlin_at_th_sem</th><td>9</td></tr><tr><th>mean_nonlin_suprath</th><td>129.0</td></tr><tr><th>nonlin_suprath_sem</th><td>6.0</td></tr><tr><th>mean_peak_deriv</th><td>2.6 V/s</td></tr><tr><th>peak_deriv_sem</th><td>0.4 V/s</td></tr><tr><th>mean_amp_at_th</th><td>4.828 mV</td></tr><tr><th>amp_at_th_sem</th><td>0.28 mV</td></tr><tr><th>mean_time_to_peak</th><td>13.5 ms</td></tr><tr><th>time_to_peak_sem</th><td>0.2 ms</td></tr><tr><th>mean_async_nonlin</th><td>104.0</td></tr><tr><th>async_nonlin_sem</th><td>8.0</td></tr><tr><th>async_n</th><td>23</td></tr></table>

# %%
#setting synapse parameters
model.AMPA_tau1 = 0.2
model.AMPA_tau2 = 5

# Instantiate the test class
test = tests.ObliqueIntegrationTest(observation = observation, save_all = True, force_run_synapse=False, force_run_bin_search=False, show_plot = True, base_directory = base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# Dendrites and locations to be tested:  [['dendA5_00', 0.2096774193548387, 'prox'], ['dendA5_00', 0.6290322580645158, 'dist'], ['dendA5_0100', 0.6428571428571428, 'prox'], ['dendA5_0100', 0.9, 'dist'], ['dendA5_0101', 0.5909090909090909, 'prox'], ['dendA5_0101', 0.9, 'dist'], ['dendA5_01100', 0.1511627906976744, 'prox'], ['dendA5_01100', 0.4302325581395347, 'dist'], ['dendA5_011010', 0.6428571428571428, 'prox'], ['dendA5_011010', 0.9, 'dist'], ['dendA5_0110110', 0.5, 'prox'], ['dendA5_0110110', 0.9, 'dist'], ['dendA5_0110111', 0.34210526315789475, 'prox'], ['dendA5_0110111', 0.8157894736842102, 'dist'], ['dendA5_01110', 0.7, 'prox'], ['dendA5_01110', 0.9, 'dist']]
#
# The built in Exp2Syn is used as the AMPA component. Tau1 = 0.2 ,Tau2 = 5 .
#
#
# The default NMDA model of HippoUnit is used with Jahr, Stevens voltage dependence.
#
# Adjusting synaptic weights on all the locations ...
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.209677419355
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.629032258065
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.642857142857
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.590909090909
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.151162790698
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.43023255814
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.642857142857
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.5
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.342105263158
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.815789473684
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.7
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.9
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/oblique_integration/Katz_et_al_2009/
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/results/oblique_integration/Katz_et_al_2009/
# === Model Katz_et_al_2009 achieved score ZScore_avg = 0.87 on test 'Oblique integration test'. ===
