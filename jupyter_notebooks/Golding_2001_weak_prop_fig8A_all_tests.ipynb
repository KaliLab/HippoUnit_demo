# %%
% matplotlib inline

from hippounit.utils import ModelLoader
from hippounit import tests

from json2html import *
import pkg_resources
import json
import collections
import numpy
import IPython
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1405: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# # Figure 8 A - Weak propagating

# %%
# path to mod files
mod_files_path = "/home/saray/published_models/Golding_et_al_2001_dichotomy/fig08/"

#all the outputs will be saved here. It will be an argument to the test.
base_directory = '/mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/'

#Load cell model
model = ModelLoader(mod_files_path = mod_files_path )

# outputs will be saved in subfolders named like this:
model.name="Golding_2001_weak_prop_fig8A"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "/home/saray/published_models/Golding_et_al_2001_dichotomy/fig08/main_model_weak_prop_fig8A.hoc"

# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = 'somaA'

# For the PSP Attenuation Test, and Back-propagating AP Test a section list containing the trunk sections is needed
model.TrunkSecList_name = 'primary_apical_list'
# For the Oblique Integration Test a section list containing the oblique dendritic sections is needed
model.ObliqueSecList_name = 'oblique_dendrites'


model.v_init = -70
model.celsius = 35

# %% [markdown]
# ### Somatic Features Test - UCL data set

# %%
# Load target data
with open('/home/saray/target_features/feat_CA1_pyr_cACpyr_more_features.json') as f:
    config_pyr = json.load(f, object_pairs_hook=collections.OrderedDict)
    
observation = config_pyr

# %%
# Load stimuli file
ttype = "CA1_pyr_cACpyr"

stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_" + ttype + ".json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'UCL_data'

# Number of parallel processes
test.npool = 30
    
try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# - running amplitude: -1.0 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: -0.6 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: -0.4 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: -0.8 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: -0.2 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.2 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.4 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.6 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.0 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.8 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/somaticfeat_UCL_data/Golding_2001_weak_prop_fig8A/
# Number of features succesfully evaluated: 232/232
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/results/somaticfeat_UCL_data/Golding_2001_weak_prop_fig8A/
# === Model Golding_2001_weak_prop_fig8A achieved score ZScore_avg = 3.15 on test 'Somatic features test'. ===

# %% [markdown]
# ### Somatic Features Test - JMakara data set

# %%
# Load target data
with open('/home/saray/target_features/feat_rat_CA1_JMakara_more_features.json') as f:
    config_pyr = json.load(f, object_pairs_hook=collections.OrderedDict)
    
observation = config_pyr

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_rat_CA1_PC_JMakara.json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'JMakara_data'

# Number of parallel processes
test.npool = 30

try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# - running amplitude: -0.25 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: -0.2 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: -0.15 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: -0.05 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: -0.1 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.05 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.1 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.15 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.2 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.25 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/somaticfeat_JMakara_data/Golding_2001_weak_prop_fig8A/
# Number of features succesfully evaluated: 305/305
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/results/somaticfeat_JMakara_data/Golding_2001_weak_prop_fig8A/
# === Model Golding_2001_weak_prop_fig8A achieved score ZScore_avg = 4.27 on test 'Somatic features test'. ===

# %% [markdown]
# ### PSP Attenuatuion Test

# %%
# Load target data
with open("/home/saray/target_features/feat_PSP_attenuation_target_data.json", 'r') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_attenuation_soma/dend_100_um</th><td>0.67037891837</td></tr><tr><th>std_attenuation_soma/dend_100_um</th><td>0.0745536001493</td></tr><tr><th>mean_attenuation_soma/dend_200_um</th><td>0.485024302539</td></tr><tr><th>std_attenuation_soma/dend_200_um</th><td>0.108372269307</td></tr><tr><th>mean_attenuation_soma/dend_300_um</th><td>0.282118043034</td></tr><tr><th>std_attenuation_soma/dend_300_um</th><td>0.0482703550105</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/PSP_attenuation_stim/stim_PSP_attenuation_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate test class 
test = tests.PSPAttenuationTest(config=config, observation=observation, num_of_dend_locations = 15, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)
            
# Number of parallel processes
test.npool = 30

try: 
    # Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('dendA5_01111111111111', 0.045454545454545456): 283.447816389045, ('dendA5_01', 0.8636363636363638): 77.09033393311545, ('dendA5_0111111111111', 0.21428571428571427): 254.78367321852483, ('dendA5_011', 0.30000000000000004): 91.2775915157409, ('dendA5_0111111111111', 0.9285714285714284): 278.8585387217133, ('dendA5_011111111111', 0.5): 239.79096715191383, ('dendA5_01111111111111', 0.13636363636363635): 287.8113986230707, ('dendA5_01111111111111', 0.9545454545454547): 327.083638729302, ('dendA5_0111111111111', 0.07142857142857142): 249.96870011788712, ('dendA5_011', 0.8999999999999999): 103.9835181978471, ('dendA5_01111111111111', 0.6818181818181819): 313.99289202722485, ('dendA5_01111', 0.9285714285714284): 142.45692935032375, ('dendA5_01', 0.40909090909090906): 50.976019794540925, ('dendA5_0111111111', 0.5): 213.20068049562843, ('dendA5_0111111111111', 0.3571428571428571): 259.5986463191625}
# input at: dendA5_01111(0.928571428571) with weight: 0.0
# input at: dendA5_01(0.863636363636) with weight: 0.0
# input at: dendA5_0111111111111(0.0714285714286) with weight: 0.0
# input at: dendA5_01(0.409090909091) with weight: 0.0
# input at: dendA5_011111111111(0.5) with weight: 0.0
# input at: dendA5_0111111111111(0.214285714286) with weight: 0.0
# input at: dendA5_011(0.9) with weight: 0.0
# input at: dendA5_0111111111111(0.357142857143) with weight: 0.0
# input at: dendA5_01111111111111(0.0454545454545) with weight: 0.0
# input at: dendA5_01111111111111(0.136363636364) with weight: 0.0
# input at: dendA5_011(0.3) with weight: 0.0
# input at: dendA5_0111111111(0.5) with weight: 0.0
# input at: dendA5_01111111111111(0.681818181818) with weight: 0.0
# input at: dendA5_0111111111111(0.928571428571) with weight: 0.0
# input at: dendA5_01111111111111(0.954545454545) with weight: 0.0
# input at: dendA5_0111111111111(0.214285714286) with weight: 0.0004078382514212537
# input at: dendA5_01(0.863636363636) with weight: 0.00041076519212200505
# input at: dendA5_01111111111111(0.0454545454545) with weight: 0.0004075140517339517
# input at: dendA5_011(0.3) with weight: 0.00041056713865687675
# input at: dendA5_0111111111111(0.928571428571) with weight: 0.0004075709483086238
# input at: dendA5_01111111111111(0.681818181818) with weight: 0.00040717318312418973
# input at: dendA5_01111111111111(0.136363636364) with weight: 0.00040746345959952445
# input at: dendA5_01111111111111(0.954545454545) with weight: 0.0004070604420446153
# input at: dendA5_0111111111111(0.0714285714286) with weight: 0.0004078874863837581
# input at: dendA5_011(0.9) with weight: 0.0004103802230792544
# input at: dendA5_011111111111(0.5) with weight: 0.00040800185555388583
# input at: dendA5_01111(0.928571428571) with weight: 0.00040960874233273565
# input at: dendA5_01(0.409090909091) with weight: 0.0004111234754537409
# input at: dendA5_0111111111(0.5) with weight: 0.0004083143806456498
# input at: dendA5_0111111111111(0.357142857143) with weight: 0.0004077894872980327
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/PSP_attenuation/Golding_2001_weak_prop_fig8A/
# === Model Golding_2001_weak_prop_fig8A achieved score ZScore_avg = 1.04 on test 'PSP attenuation test'. ===

# %% [markdown]
# ### Back-Propagating AP Test

# %%
# Load target data
with open('/home/saray/target_features/feat_backpropagating_AP_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

#observation = config['features']
IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_AP1_amp_at_50um</th><td>66.6474010216 mV</td></tr><tr><th>std_AP1_amp_at_50um</th><td>7.6800611053 mV</td></tr><tr><th>mean_AP1_amp_at_150um</th><td>61.6405452338 mV</td></tr><tr><th>std_AP1_amp_at_150um</th><td>8.84061901299 mV</td></tr><tr><th>mean_AP1_amp_at_250um</th><td>57.1478276286 mV</td></tr><tr><th>std_AP1_amp_at_250um</th><td>6.74288151869 mV</td></tr><tr><th>mean_AP1_amp_strong_propagating_at_350um</th><td>52.5065653152 mV</td></tr><tr><th>std_AP1_amp_strong_propagating_at_350um</th><td>5.82443856294 mV</td></tr><tr><th>mean_AP1_amp_weak_propagating_at_350um</th><td>18.7832282514 mV</td></tr><tr><th>std_AP1_amp_weak_propagating_at_350um</th><td>1.87203344953 mV</td></tr><tr><th>mean_APlast_amp_at_50um</th><td>56.0027067193 mV</td></tr><tr><th>std_APlast_amp_at_50um</th><td>6.66451614848 mV</td></tr><tr><th>mean_APlast_amp_at_150um</th><td>41.6724147741 mV</td></tr><tr><th>std_APlast_amp_at_150um</th><td>7.62175409041 mV</td></tr><tr><th>mean_APlast_amp_at_250um</th><td>21.1507839635 mV</td></tr><tr><th>std_APlast_amp_at_250um</th><td>2.39551093081 mV</td></tr><tr><th>mean_APlast_amp_at_350um</th><td>9.81008709754 mV</td></tr><tr><th>std_APlast_amp_at_350um</th><td>3.67378280696 mV</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/bAP_stim/stim_bAP_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate the test class
test = tests.BackpropagatingAPTest(config=config, observation=observation, force_run=False, force_run_FindCurrentStim=False, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 30

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('dendA5_011111', 0.5): 150.49165189616144, ('dendA5_01', 0.045454545454545456): 30.084568483681313, ('dendA5_0111111111111111', 0.20588235294117646): 354.715732316079, ('dendA5_011111111111111', 0.8333333333333333): 337.0317515174673, ('dendA5_0111111111111111', 0.3823529411764706): 368.5420607141201, ('dendA5_01', 0.40909090909090906): 50.976019794540925, ('dendA5_011111', 0.16666666666666666): 146.61781983044364, ('dendA5_01', 0.22727272727272727): 40.53029413911112, ('dendA5_01', 0.5909090909090909): 61.42174544997073, ('dendA5_0111111111111111', 0.2647058823529412): 359.3245084487594, ('dendA5_01111', 0.7857142857142856): 138.0089804558018, ('dendA5_0111111', 0.21428571428571427): 163.53624562999937, ('dendA5_011111', 0.8333333333333333): 154.36548396187922, ('dendA5_011111111111', 0.5): 239.79096715191383, ('dendA5_01111', 0.9285714285714284): 142.45692935032375, ('dendA5_0111111111111', 0.3571428571428571): 259.5986463191625, ('dendA5_01', 0.6818181818181819): 66.64460827768563, ('dendA5_0111111111111111', 0.14705882352941174): 350.10695618339867, ('dendA5_011111111111111', 0.5): 333.9252228490063, ('dendA5_011111111111111', 0.16666666666666666): 330.8186941805453, ('dendA5_0111111111111', 0.49999999999999994): 264.4136194198002, ('dendA5_0111111111111', 0.07142857142857142): 249.96870011788712, ('dendA5_01', 0.13636363636363635): 35.307431311396215, ('dendA5_01', 0.5): 56.19888262225582, ('dendA5_0111111111111111', 0.029411764705882353): 340.88940391803794, ('dendA5_0111111', 0.07142857142857142): 158.71368187315855, ('dendA5_0111111111111111', 0.3235294117647059): 363.93328458143975, ('dendA5_0111111111111', 0.21428571428571427): 254.78367321852483, ('dendA5_01111', 0.6428571428571428): 133.56103156127986, ('dendA5_011111111111', 0.8333333333333333): 244.9711314290168, ('dendA5_0111111', 0.3571428571428571): 168.35880938684022, ('dendA5_011111111111', 0.16666666666666666): 234.61080287481082, ('dendA5_0111111111111', 0.6428571428571428): 269.2285925204379, ('dendA5_01', 0.3181818181818182): 45.75315696682602, ('dendA5_0111111111111111', 0.08823529411764705): 345.4981800507183, ('dendA5_01111111111', 0.8333333333333333): 230.5970310460218}
# Finding appropriate current step amplitude...
# - running amplitude: 0.0 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.1 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.2 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.30000000000000004 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.4 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.5 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.9 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.8 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.0 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.6000000000000001 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.7000000000000001 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.13999999999999999 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.16999999999999998 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.14999999999999997 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.14500000000000005 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.17000000000000007 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.15500000000000005 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.15000000000000005 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.14750000000000005 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.12250000000000003 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.13500000000000004 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.14000000000000004 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.14250000000000004 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# WARNING: No current amplitude value has been found to which the model's firing frequency is between 10 and 20 Hz. The simulation is done using the current amplitude value to which the models fires at a frequency nearest to 15 Hz, but not 0 Hz. Current step amplitude: 0.14750000000000005nA, frequency: [23]Hz
#
# - running amplitude: 0.14750000000000005 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/backpropagating_AP/Golding_2001_weak_prop_fig8A/
# This is a rather WEAK propagating model
# === Model Golding_2001_weak_prop_fig8A achieved score Z_score_avg_WEAK_propagating = 2.90 on test 'Back-propagating action potential test'. ===

# %% [markdown]
# ### Depolarization-block Test

# %%
# Load target data
with open('/home/saray/target_features/depol_block_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

#observation = config['features']
IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_Ith</th><td>0.6 nA</td></tr><tr><th>Ith_std</th><td>0.3 nA</td></tr><tr><th>mean_Veq</th><td>-40.1 mV</td></tr><tr><th>Veq_std</th><td>3.4 mV</td></tr></table>

# %%
# Instantiate the test class

test = tests.DepolarizationBlockTest(observation=observation, force_run=False, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 30

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# - running amplitude: 0.0 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.1 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.05 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.15000000000000002 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.2 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.30000000000000004 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.25 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.35000000000000003 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.45 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.4 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.5 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.55 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.6000000000000001 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.65 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.7000000000000001 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.75 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.8 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.8500000000000001 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.0 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.9500000000000001 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 0.9 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.05 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.1 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.1500000000000001 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.2000000000000002 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.25 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.3 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.35 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.4000000000000001 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.4500000000000002 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.5 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.55 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# - running amplitude: 1.6 on model: Golding_2001_weak_prop_fig8A at: somaA(0.5)
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/depol_block/Golding_2001_weak_prop_fig8A/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.6 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): nan nA
# Veq (the equilibrium value during the depolarization block): nan mV
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/results/depol_block/Golding_2001_weak_prop_fig8A/
# The model did not enter depolarization block.
# === Model Golding_2001_weak_prop_fig8A achieved score ZScore_avg+penalty = 100.00 on test 'Depolarization block test'. ===

# %% [markdown]
# ### Oblique Integration Test

# %%
# Load target data
with open('/home/saray/target_features/oblique_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_threshold</th><td>3.4 mV</td></tr><tr><th>threshold_sem</th><td>0.2 mV</td></tr><tr><th>exp_n</th><td>92</td></tr><tr><th>mean_prox_threshold</th><td>4.5 mV</td></tr><tr><th>prox_threshold_sem</th><td>0.5 mV</td></tr><tr><th>prox_n</th><td>33</td></tr><tr><th>mean_dist_threshold</th><td>2.6 mV</td></tr><tr><th>dist_threshold_sem</th><td>0.2 mV</td></tr><tr><th>dist_n</th><td>44</td></tr><tr><th>mean_nonlin_at_th</th><td>142</td></tr><tr><th>nonlin_at_th_sem</th><td>9</td></tr><tr><th>mean_nonlin_suprath</th><td>129.0</td></tr><tr><th>nonlin_suprath_sem</th><td>6.0</td></tr><tr><th>mean_peak_deriv</th><td>2.6 V/s</td></tr><tr><th>peak_deriv_sem</th><td>0.4 V/s</td></tr><tr><th>mean_amp_at_th</th><td>4.828 mV</td></tr><tr><th>amp_at_th_sem</th><td>0.28 mV</td></tr><tr><th>mean_time_to_peak</th><td>13.5 ms</td></tr><tr><th>time_to_peak_sem</th><td>0.2 ms</td></tr><tr><th>mean_async_nonlin</th><td>104.0</td></tr><tr><th>async_nonlin_sem</th><td>8.0</td></tr><tr><th>async_n</th><td>23</td></tr></table>

# %%
# Instantiate the test class
test = tests.ObliqueIntegrationTest(observation = observation, save_all = True, force_run_synapse=False, force_run_bin_search=False, show_plot = True, base_directory = base_directory)

# Number of parallel processes
test.npool = 30

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print 'Model: ' + model.name + ' could not be run'
    print e
    pass
# Out:
# Dendrites and locations to be tested:  [['dendA5_00', 0.22499999999999998, 'prox'], ['dendA5_00', 0.625, 'dist'], ['dendA5_0101', 0.6428571428571428, 'prox'], ['dendA5_0101', 0.9, 'dist'], ['dendA5_0100', 0.7, 'prox'], ['dendA5_0100', 0.9, 'dist'], ['dendA5_01110', 0.875, 'prox'], ['dendA5_01110', 0.9, 'dist'], ['dendA5_01100', 0.1956521739130435, 'prox'], ['dendA5_01100', 0.4565217391304347, 'dist'], ['dendA5_011010', 0.875, 'prox'], ['dendA5_011010', 0.9, 'dist'], ['dendA5_0110111', 0.35, 'prox'], ['dendA5_0110111', 0.8499999999999999, 'dist'], ['dendA5_0110110', 0.6428571428571428, 'prox'], ['dendA5_0110110', 0.9, 'dist']]
#
# The built in Exp2Syn is used as the AMPA component. Tau1 = 0.1 ,Tau2 = 2.0 .
#
#
# The default NMDA model of HippoUnit is used with Jahr, Stevens voltage dependence.
#
# Adjusting synaptic weights on all the locations ...
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.225
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.642857142857
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.195652173913
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.45652173913
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.85
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.642857142857
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.9
# The figures are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/figs/oblique_integration/Golding_2001_weak_prop_fig8A/
# Results are saved in the directory:  /mnt/csoport31-2/Modellezo_csapat/Sara/published_models_validation_results/results/oblique_integration/Golding_2001_weak_prop_fig8A/
# === Model Golding_2001_weak_prop_fig8A achieved score ZScore_avg = 1.03 on test 'Oblique integration test'. ===
