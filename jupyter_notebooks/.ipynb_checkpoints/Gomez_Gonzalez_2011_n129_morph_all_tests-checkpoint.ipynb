# %% [markdown]
# # Run validation tests of HippoUnit on the Gómez González et al. 2011 model of hippocampal CA1 pyramidal cell
#
# The purpose of this notebook is to show how to run the validation tests of HippoUnit (https://github.com/KaliLab/hippounit) on the Gómez González et al. 2011 CA1 pyramidal cell model (ModelDB accession number: 144450).
#
# The tests shall take as input a standalone version of the model (a hoc file) that should not display any GUI, or contain any built in simulations and run-time modifications.
# __In this notebook the version of the model is tested that uses the n129 morphology__.
# The hoc file that is used in this notebook is available here:
# https://github.com/KaliLab/HippoUnit_demo/blob/master/published_models/CA1_Gomez_2011/experiment/junio/main_model_n129_morph.hoc
#
# Target experimental data that are used by the validation tests in this notebook are available here:
# https://github.com/KaliLab/HippoUnit_demo/tree/master/target_features

# %%
from __future__ import print_function

# %matplotlib inline

from hippounit.utils import ModelLoader
from hippounit import tests

from json2html import *
import pkg_resources
import json
import collections
import numpy
import IPython

# %% [markdown]
# ## Instantiating the model
#
# The ModelLoader class of HippoUnit is instantiated and the model, and simulation related parameters are set.

# %%
# path to mod files
mod_files_path = "../published_models/CA1_Gomez_2011/mechanism/"

#all the outputs will be saved here. It will be an argument to the test.
base_directory = '../published_models_validation_results/'

#Load cell model
model = ModelLoader(mod_files_path = mod_files_path )

# outputs will be saved in subfolders named like this:
model.name="Gomez_Gonzalez_2011_n129_morph"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "../published_models/CA1_Gomez_2011/experiment/junio/main_model_n129_morph.hoc"

# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = 'soma[0]'

# For the PSP Attenuation Test, and Back-propagating AP Test a section list containing the trunk sections is needed
model.TrunkSecList_name = 'apical_trunk_list'
# For the Oblique Integration Test a section list containing the oblique dendritic sections is needed
model.ObliqueSecList_name = 'oblique_dendrites'

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -66
model.celsius = 34

# %% [markdown]
# ## Instantiating and running the tests of HippoUnit on the model
#
# At the end of each test, the user is provided with a textual summary of the score and the path to related output files generated by the tests.

# %% [markdown]
# ### Somatic Features Test - UCL data set
#
# It evaluates the model against various eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection of varying amplitudes. The experimental dataset used for validation is obtained from sharp electrode recordings in rats at UCL (Migliore et al. 2018  https://doi.org/10.1371/journal.pcbi.1006423).

# %%
# Load target data
with open('../target_features/feat_CA1_pyr_cACpyr_more_features.json') as f:
    config_pyr = json.load(f, object_pairs_hook=collections.OrderedDict)
    
observation = config_pyr

# %%
# Load stimuli file
ttype = "CA1_pyr_cACpyr"

stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_" + ttype + ".json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'UCL_data'

# Number of parallel processes
test.npool = 10
    
try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: -1.0 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.0 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: -0.2 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: -0.6 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: -0.8 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.4 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.2 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.8 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: -0.4 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.6 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/somaticfeat_UCL_data/Gomez_Gonzalez_2011_n129_morph/
# Number of features succesfully evaluated: 232/232
# Results are saved in the directory:  ../published_models_validation_results/results/somaticfeat_UCL_data/Gomez_Gonzalez_2011_n129_morph/
# === Model Gomez_Gonzalez_2011_n129_morph achieved score ZScore_avg = 6.13 on test 'Somatic features test'. ===

# %% [markdown]
# ### Somatic Features Test - JMakara data set
#
# It evaluates the model against various eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection of varying amplitudes. The experimental dataset used for validation is obtained from patch clamp recordings in rats by Judit Makara.

# %%
# Load target data
with open('../target_features/feat_rat_CA1_JMakara_more_features.json') as f:
    config_pyr = json.load(f, object_pairs_hook=collections.OrderedDict)
    
observation = config_pyr

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_rat_CA1_PC_JMakara.json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'JMakara_data'

# Number of parallel processes
test.npool = 10

try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: 0.25 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.15 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: -0.1 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: -0.2 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: -0.25 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.2 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.05 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: -0.15 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: -0.05 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.1 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/somaticfeat_JMakara_data/Gomez_Gonzalez_2011_n129_morph/
# Number of features succesfully evaluated: 305/305
# Results are saved in the directory:  ../published_models_validation_results/results/somaticfeat_JMakara_data/Gomez_Gonzalez_2011_n129_morph/
# === Model Gomez_Gonzalez_2011_n129_morph achieved score ZScore_avg = 4.48 on test 'Somatic features test'. ===

# %% [markdown]
# ### PSP Attenuatuion Test
#
# The PSP Attenuation Test evaluates how much the post synaptic potential (using EPSC stimulus) attenuates from the main apical dendrite (different distances) to the soma. The soma/dendrite attenuation is compared to data from Magee & Cook 2000 (http://dx.doi.org/10.1038/78800).

# %%
# Load target data
with open("../target_features/feat_PSP_attenuation_target_data.json", 'r') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_attenuation_soma/dend_100_um</th><td>0.67037891837</td></tr><tr><th>std_attenuation_soma/dend_100_um</th><td>0.0745536001493</td></tr><tr><th>mean_attenuation_soma/dend_200_um</th><td>0.485024302539</td></tr><tr><th>std_attenuation_soma/dend_200_um</th><td>0.108372269307</td></tr><tr><th>mean_attenuation_soma/dend_300_um</th><td>0.282118043034</td></tr><tr><th>std_attenuation_soma/dend_300_um</th><td>0.0482703550105</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/PSP_attenuation_stim/stim_PSP_attenuation_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate test class 
test = tests.PSPAttenuationTest(config=config, observation=observation, num_of_dend_locations = 15, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)
            
# Number of parallel processes
test.npool = 10

try: 
    # Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('trunk[4]', 0.5): 102.47762241797938, ('trunk[1]', 0.30000000000000004): 57.61428496667684, ('trunk[0]', 0.8999999999999999): 50.89491199669502, ('trunk[12]', 0.7): 281.37464601855845, ('trunk[13]', 0.1): 305.60211030509345, ('trunk[7]', 0.30000000000000004): 180.37072321249076, ('trunk[12]', 0.1): 242.71230958135067, ('trunk[7]', 0.5): 185.4673099420653, ('trunk[7]', 0.8999999999999999): 195.66048340121438, ('trunk[7]', 0.1): 175.27413648291622, ('trunk[2]', 0.5): 67.824925546124, ('trunk[11]', 0.1): 202.4385331915214, ('trunk[13]', 0.30000000000000004): 315.39470244095565, ('trunk[13]', 0.8999999999999999): 344.7724788485422, ('trunk[12]', 0.8999999999999999): 294.2620914976277}
# input at: trunk[12](0.7) with weight: 0.0
# input at: trunk[1](0.30000000000000004) with weight: 0.0
# input at: trunk[4](0.5) with weight: 0.0
# input at: trunk[7](0.8999999999999999) with weight: 0.0
# input at: trunk[13](0.30000000000000004) with weight: 0.0
# input at: trunk[7](0.30000000000000004) with weight: 0.0
# input at: trunk[12](0.1) with weight: 0.0
# input at: trunk[12](0.8999999999999999) with weight: 0.0
# input at: trunk[13](0.1) with weight: 0.0
# input at: trunk[0](0.8999999999999999) with weight: 0.0
# input at: trunk[7](0.1) with weight: 0.0
# input at: trunk[11](0.1) with weight: 0.0
# input at: trunk[13](0.8999999999999999) with weight: 0.0
# input at: trunk[7](0.5) with weight: 0.0
# input at: trunk[2](0.5) with weight: 0.0
# input at: trunk[12](0.1) with weight: 0.0004542407468489278
# input at: trunk[4](0.5) with weight: 0.0004541325677978207
# input at: trunk[1](0.30000000000000004) with weight: 0.00045411939626331763
# input at: trunk[13](0.30000000000000004) with weight: 0.0004542912934609284
# input at: trunk[12](0.7) with weight: 0.00045427150623241337
# input at: trunk[7](0.1) with weight: 0.0004541877117912962
# input at: trunk[0](0.8999999999999999) with weight: 0.00045411900379236546
# input at: trunk[2](0.5) with weight: 0.0004541208904433316
# input at: trunk[7](0.30000000000000004) with weight: 0.00045419204618328833
# input at: trunk[7](0.8999999999999999) with weight: 0.0004542050325833019
# input at: trunk[7](0.5) with weight: 0.0004541963777389117
# input at: trunk[11](0.1) with weight: 0.0004542106923255361
# input at: trunk[13](0.1) with weight: 0.0004542865325362942
# input at: trunk[13](0.8999999999999999) with weight: 0.00045430542067665725
# input at: trunk[12](0.8999999999999999) with weight: 0.0004542800317344869
# The figures are saved in the directory:  ../published_models_validation_results/figs/PSP_attenuation/Gomez_Gonzalez_2011_n129_morph/
# === Model Gomez_Gonzalez_2011_n129_morph achieved score ZScore_avg = 2.28 on test 'PSP attenuation test'. ===

# %% [markdown]
# ### Back-Propagating AP Test
#
# The Back-Propagating AP Test evaluates the mode and efficacy of back-propagating action potentials on the apical trunk in locations of different distances from the soma. The amplitude of the first and last AP of around 15 Hz train is compared to experimental data from Golding et al. 2001 (https://doi.org/10.1152/jn.2001.86.6.2998).

# %%
# Load target data
with open('../target_features/feat_backpropagating_AP_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

#observation = config['features']
IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_AP1_amp_at_50um</th><td>66.6474010216 mV</td></tr><tr><th>std_AP1_amp_at_50um</th><td>7.6800611053 mV</td></tr><tr><th>mean_AP1_amp_at_150um</th><td>61.6405452338 mV</td></tr><tr><th>std_AP1_amp_at_150um</th><td>8.84061901299 mV</td></tr><tr><th>mean_AP1_amp_at_250um</th><td>57.1478276286 mV</td></tr><tr><th>std_AP1_amp_at_250um</th><td>6.74288151869 mV</td></tr><tr><th>mean_AP1_amp_strong_propagating_at_350um</th><td>52.5065653152 mV</td></tr><tr><th>std_AP1_amp_strong_propagating_at_350um</th><td>5.82443856294 mV</td></tr><tr><th>mean_AP1_amp_weak_propagating_at_350um</th><td>18.7832282514 mV</td></tr><tr><th>std_AP1_amp_weak_propagating_at_350um</th><td>1.87203344953 mV</td></tr><tr><th>mean_APlast_amp_at_50um</th><td>56.0027067193 mV</td></tr><tr><th>std_APlast_amp_at_50um</th><td>6.66451614848 mV</td></tr><tr><th>mean_APlast_amp_at_150um</th><td>41.6724147741 mV</td></tr><tr><th>std_APlast_amp_at_150um</th><td>7.62175409041 mV</td></tr><tr><th>mean_APlast_amp_at_250um</th><td>21.1507839635 mV</td></tr><tr><th>std_APlast_amp_at_250um</th><td>2.39551093081 mV</td></tr><tr><th>mean_APlast_amp_at_350um</th><td>9.81008709754 mV</td></tr><tr><th>std_APlast_amp_at_350um</th><td>3.67378280696 mV</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/bAP_stim/stim_bAP_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate the test class
test = tests.BackpropagatingAPTest(config=config, observation=observation, force_run=False, force_run_FindCurrentStim=False, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('trunk[1]', 0.7): 59.751304100827745, ('trunk[13]', 0.7): 334.97988671268, ('trunk[0]', 0.7): 40.66169475795776, ('trunk[6]', 0.1): 140.31851494195757, ('trunk[12]', 0.1): 242.71230958135067, ('trunk[1]', 0.5): 58.68279453375229, ('trunk[14]', 0.30000000000000004): 357.02668912551945, ('trunk[1]', 0.1): 56.54577539960138, ('trunk[14]', 0.7): 366.83724140424766, ('trunk[2]', 0.5): 67.824925546124, ('trunk[11]', 0.8999999999999999): 232.5096919917833, ('trunk[0]', 0.8999999999999999): 50.89491199669502, ('trunk[2]', 0.1): 62.648239870377544, ('trunk[12]', 0.5): 268.4872005394892, ('trunk[2]', 0.30000000000000004): 65.23658270825078, ('trunk[14]', 0.1): 352.12141298615535, ('trunk[5]', 0.8999999999999999): 134.34582884510445, ('trunk[6]', 0.8999999999999999): 169.12502887633212, ('trunk[12]', 0.30000000000000004): 255.59975506041994, ('trunk[6]', 0.7): 161.92340039273847, ('trunk[6]', 0.30000000000000004): 147.5201434255512, ('trunk[6]', 0.5): 154.72177190914485, ('trunk[1]', 0.8999999999999999): 60.819813667903205, ('trunk[14]', 0.5): 361.93196526488356, ('trunk[13]', 0.8999999999999999): 344.7724788485422, ('trunk[0]', 0.5): 30.428477519220493, ('trunk[1]', 0.30000000000000004): 57.61428496667684}
# Finding appropriate current step amplitude...
# - running amplitude: 0.0 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.1 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.30000000000000004 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.6000000000000001 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.9 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.2 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.8 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.5 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.4 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.7000000000000001 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.0 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.4 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/backpropagating_AP/Gomez_Gonzalez_2011_n129_morph/
# This is a rather STRONG propagating model
# === Model Gomez_Gonzalez_2011_n129_morph achieved score Z_score_avg_STRONG_propagating = 1.79 on test 'Back-propagating action potential test'. ===

# %% [markdown]
# ### Depolarization-block Test
#
# The Depolarization Block Test aims to determine whether the model enters depolarization block to prolonged, high intensity somatic current stimulus. It compares the current intensity to which the model fires the maximum number of action potentials, the current intensity before the model enters depolarization block (the two should be equal) and the equilibrium potential during depolarization block to the experimental data of Bianchi et al. 2012 (http://dx.doi.org/10.1007/s10827-012-0383-y).

# %%
# Load target data
with open('../target_features/depol_block_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

#observation = config['features']
IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_Ith</th><td>0.6 nA</td></tr><tr><th>Ith_std</th><td>0.3 nA</td></tr><tr><th>mean_Veq</th><td>-40.1 mV</td></tr><tr><th>Veq_std</th><td>3.4 mV</td></tr></table>

# %%
# Instantiate the test class

test = tests.DepolarizationBlockTest(observation=observation, force_run=False, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: 0.15000000000000002 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.0 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.4 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.1 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.30000000000000004 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.45 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.25 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.2 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.35000000000000003 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.05 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.5 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.55 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.6000000000000001 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.65 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.7000000000000001 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.75 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.8 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.8500000000000001 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.9 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 0.9500000000000001 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.0 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.05 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.1 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.1500000000000001 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.2000000000000002 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.25 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.3 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.35 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.4000000000000001 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.4500000000000002 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.5 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.55 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# - running amplitude: 1.6 on model: Gomez_Gonzalez_2011_n129_morph at: soma[0](0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/depol_block/Gomez_Gonzalez_2011_n129_morph/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.4000000000000001 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 1.4000000000000001 nA
# Veq (the equilibrium value during the depolarization block): -52.21096058485405 mV
# Results are saved in the directory:  ../published_models_validation_results/results/depol_block/Gomez_Gonzalez_2011_n129_morph/
# === Model Gomez_Gonzalez_2011_n129_morph achieved score ZScore_avg+penalty = 2.97 on test 'Depolarization block test'. ===

# %% [markdown]
# ### Oblique Integration Test
#
# Tests signal integration in oblique dendrites for increasing number of synchronous and asynchronous synaptic inputs. The experimental data is obtained from Losonczy and Magee 2006 (https://doi.org/10.1016/j.neuron.2006.03.016).

# %%
# Load target data
with open('../target_features/oblique_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_threshold</th><td>3.4 mV</td></tr><tr><th>threshold_sem</th><td>0.2 mV</td></tr><tr><th>exp_n</th><td>92</td></tr><tr><th>mean_prox_threshold</th><td>4.5 mV</td></tr><tr><th>prox_threshold_sem</th><td>0.5 mV</td></tr><tr><th>prox_n</th><td>33</td></tr><tr><th>mean_dist_threshold</th><td>2.6 mV</td></tr><tr><th>dist_threshold_sem</th><td>0.2 mV</td></tr><tr><th>dist_n</th><td>44</td></tr><tr><th>mean_nonlin_at_th</th><td>142</td></tr><tr><th>nonlin_at_th_sem</th><td>9</td></tr><tr><th>mean_nonlin_suprath</th><td>129.0</td></tr><tr><th>nonlin_suprath_sem</th><td>6.0</td></tr><tr><th>mean_peak_deriv</th><td>2.6 V/s</td></tr><tr><th>peak_deriv_sem</th><td>0.4 V/s</td></tr><tr><th>mean_amp_at_th</th><td>4.828 mV</td></tr><tr><th>amp_at_th_sem</th><td>0.28 mV</td></tr><tr><th>mean_time_to_peak</th><td>13.5 ms</td></tr><tr><th>time_to_peak_sem</th><td>0.2 ms</td></tr><tr><th>mean_async_nonlin</th><td>104.0</td></tr><tr><th>async_nonlin_sem</th><td>8.0</td></tr><tr><th>async_n</th><td>23</td></tr></table>

# %%
#setting synapse parameters

# If model.AMPA_name and/or model.NMDA_name is set here, the model's own receptor models (mod files) are used. 
# If these are not set, HippoUnit's default synapse model is used. (AMPA: NEURON's Exp2Syn, NMDA: https://github.com/KaliLab/hippounit/blob/master/hippounit/tests/default_NMDAr/NMDA_CA1_pyr_SC.mod) 

model.NMDA_name = 'NMDA'
model.AMPA_name = 'GLU'
model.AMPA_NMDA_ratio = 1/0.396

# Instantiate the test class
test = tests.ObliqueIntegrationTest(observation = observation, save_all = True, force_run_synapse=False, force_run_bin_search=False, show_plot = True, base_directory = base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# Dendrites and locations to be tested:  [['apical_dendrite[76]', 0.5, 'prox'], ['apical_dendrite[76]', 0.9, 'dist'], ['apical_dendrite[77]', 0.5, 'prox'], ['apical_dendrite[77]', 0.9, 'dist'], ['apical_dendrite[78]', 0.5, 'prox'], ['apical_dendrite[78]', 0.9, 'dist'], ['apical_dendrite[79]', 0.5, 'prox'], ['apical_dendrite[79]', 0.9, 'dist'], ['apical_dendrite[83]', 0.5, 'prox'], ['apical_dendrite[83]', 0.9, 'dist'], ['apical_dendrite[84]', 0.16666666666666666, 'prox'], ['apical_dendrite[84]', 0.5, 'dist'], ['apical_dendrite[86]', 0.5, 'prox'], ['apical_dendrite[86]', 0.9, 'dist'], ['apical_dendrite[87]', 0.25, 'prox'], ['apical_dendrite[87]', 0.75, 'dist'], ['apical_dendrite[88]', 0.5, 'prox'], ['apical_dendrite[88]', 0.9, 'dist']]
# Adjusting synaptic weights on all the locations ...
# The dendritic spike at dendrite apical_dendrite[76](0.5) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[76](0.9) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[77](0.5) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[77](0.9) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[78](0.5) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[78](0.9) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[79](0.5) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[79](0.9) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[83](0.5) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[83](0.9) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[88](0.5) generated somatic AP - this location is not used in the test
# The dendritic spike at dendrite apical_dendrite[88](0.9) generated somatic AP - this location is not used in the test
# - number of inputs: 0 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 1 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 2 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 3 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 4 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 5 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 6 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 7 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 8 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 9 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 10 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 0 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 0 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 5 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 4 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 3 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 7 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 6 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 2 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 1 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 9 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 8 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 10 dendrite: apical_dendrite[84] xloc: 0.16666666666666666
# - number of inputs: 0 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[84] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 1 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 2 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 3 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 4 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 5 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 6 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 7 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 8 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 9 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 10 dendrite: apical_dendrite[86] xloc: 0.5
# - number of inputs: 0 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 1 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 2 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 3 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 4 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 5 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 6 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 7 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 8 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 9 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 10 dendrite: apical_dendrite[86] xloc: 0.9
# - number of inputs: 0 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 1 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 2 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 3 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 4 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 5 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 6 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 7 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 8 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 9 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 10 dendrite: apical_dendrite[87] xloc: 0.25
# - number of inputs: 0 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 1 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 2 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 3 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 4 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 5 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 6 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 7 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 8 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 9 dendrite: apical_dendrite[87] xloc: 0.75
# - number of inputs: 10 dendrite: apical_dendrite[87] xloc: 0.75
# The figures are saved in the directory:  ../published_models_validation_results/figs/oblique_integration/Gomez_Gonzalez_2011_n129_morph/
# Results are saved in the directory:  ../published_models_validation_results/results/oblique_integration/Gomez_Gonzalez_2011_n129_morph/
# === Model Gomez_Gonzalez_2011_n129_morph achieved score ZScore_avg = 2.23 on test 'Oblique integration test'. ===

# %%
# %load_ext watermark

# %%
# %watermark -v -m -p sciunit,efel,numpy,quantities,scipy,matplotlib,neuron
# Out:
# CPython 3.5.2
# IPython 5.6.0
#
# sciunit 0.2.1.1
# efel 3.0.58
# numpy 1.16.4
# quantities 0.12.1
# scipy 1.3.0
# matplotlib 3.0.3
# neuron 7.6.2
#
# compiler   : GCC 5.4.0 20160609
# system     : Linux
# release    : 4.15.0-60-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 56
# interpreter: 64bit
