# %% [markdown]
# # Run validation tests of HippoUnit on the Golding et al. 2001 model of hippocampal CA1 pyramidal cell
#
# The purpose of this notebook is to show how to run the validation tests of HippoUnit (https://github.com/KaliLab/hippounit) on the Golding et al. 2001 CA1 pyramidal cell model (ModelDB accession number: 64167).
#
# The tests shall take as input a standalone version of the model (a hoc file) that should not display any GUI, or contain any built in simulations and run-time modifications.
# __In this notebook the weak propagating version of the model is tested that is shown in Figure 9 B in its paper (Golding et al. 2001 - https://doi.org/10.1152/jn.2001.86.6.2998)__.
# The hoc file that is used in this notebook is available here:
# https://github.com/KaliLab/HippoUnit_demo/blob/master/published_models/Golding_et_al_2001_dichotomy/fig09/main_model_weak_prop_fig9B.hoc
#
# Target experimental data that are used by the validation tests in this notebook are available here:
# https://github.com/KaliLab/HippoUnit_demo/tree/master/target_features

# %%
from __future__ import print_function

# %matplotlib inline

from hippounit.utils import ModelLoader
from hippounit import tests

from json2html import *
import pkg_resources
import json
import collections
import numpy
import IPython

# %% [markdown]
# # Figure 9 B - Weak propagating

# %% [markdown]
# ## Instantiating the model
#
# The ModelLoader class of HippoUnit is instantiated and the model, and simulation related parameters are set.

# %%
# path to mod files
mod_files_path = "../published_models/Golding_et_al_2001_dichotomy/fig09/"

#all the outputs will be saved here. It will be an argument to the test.
base_directory = '../published_models_validation_results/'

#Load cell model
model = ModelLoader(mod_files_path = mod_files_path )

# outputs will be saved in subfolders named like this:
model.name="Golding_2001_weak_prop_fig9B"

# path to hoc file
# the model must not display any GUI!!
model.hocpath = "../published_models/Golding_et_al_2001_dichotomy/fig09/main_model_weak_prop_fig9B.hoc"

# If the hoc file doesn't contain a template, this must be None (the default value is None)
model.template_name = None

# model.SomaSecList_name should be None, if there is no Section List in the model for the soma, or if the name of the soma section is given by setting model.soma (the default value is None)
model.SomaSecList_name = None
# if the soma is not in a section list or to use a specific somatic section, add its name here:
model.soma = 'somaA'

# For the PSP Attenuation Test, and Back-propagating AP Test a section list containing the trunk sections is needed
model.TrunkSecList_name = 'primary_apical_list'
# For the Oblique Integration Test a section list containing the oblique dendritic sections is needed
model.ObliqueSecList_name = 'oblique_dendrites'

# It is important to set the v_init and the celsius parameters of the simulations here,
# as if they are only set in the model's files, they will be overwritten with the default values of the ModelLoader class.
# default values: v_init = -70, celsius = 34 
model.v_init = -70
model.celsius = 35

# %% [markdown]
# ## Instantiating and running the tests of HippoUnit on the model
#
# At the end of each test, the user is provided with a textual summary of the score and the path to related output files generated by the tests.

# %% [markdown]
# ### Somatic Features Test - UCL data set
#
# It evaluates the model against various eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection of varying amplitudes. The experimental dataset used for validation is obtained from sharp electrode recordings in rats at UCL (Migliore et al. 2018  https://doi.org/10.1371/journal.pcbi.1006423).

# %%
# Load target data
with open('../target_features/feat_CA1_pyr_cACpyr_more_features.json') as f:
    config_pyr = json.load(f, object_pairs_hook=collections.OrderedDict)
    
observation = config_pyr

# %%
# Load stimuli file
ttype = "CA1_pyr_cACpyr"

stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_" + ttype + ".json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'UCL_data'

# Number of parallel processes
test.npool = 10
    
try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: -0.8 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: -1.0 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: -0.6 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: -0.4 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: -0.2 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.2 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.6 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.4 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.8 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.0 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/somaticfeat_UCL_data/Golding_2001_weak_prop_fig9B/
# Number of features succesfully evaluated: 232/232
# Results are saved in the directory:  ../published_models_validation_results/results/somaticfeat_UCL_data/Golding_2001_weak_prop_fig9B/
# === Model Golding_2001_weak_prop_fig9B achieved score ZScore_avg = 3.28 on test 'Somatic features test'. ===

# %% [markdown]
# ### Somatic Features Test - JMakara data set
#
# It evaluates the model against various eFEL (https://github.com/BlueBrain/eFEL) features under somatic current injection of varying amplitudes. The experimental dataset used for validation is obtained from patch clamp recordings in rats by Judit Makara.

# %%
# Load target data
with open('../target_features/feat_rat_CA1_JMakara_more_features.json') as f:
    config_pyr = json.load(f, object_pairs_hook=collections.OrderedDict)
    
observation = config_pyr

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/somafeat_stim/stim_rat_CA1_PC_JMakara.json")
with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)
    
# Instantiate test class   
test = tests.SomaticFeaturesTest(observation=observation, config=config, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)

# test.specify_data_set is added to the name of the subdirectory (somaticfeat), so test runs using different data sets can be saved into different directories
test.specify_data_set = 'JMakara_data'

# Number of parallel processes
test.npool = 10

try:
    #Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: 0.15 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: -0.25 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: -0.2 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: -0.15 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: -0.1 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: -0.05 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.05 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.25 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.2 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.1 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AHP_depth:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_values] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AHP_depth_abs:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_values] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AHP_depth_diff:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_values] is missing
#
# Feature [AHP_depth] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AHP_depth_from_peak:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AHP_time_from_peak:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_amplitude:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [peak_voltage] is missing
# AP_amplitude: Error calculating peak_voltage
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_amplitude_change:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [peak_voltage] is missing
# AP_amplitude: Error calculating peak_voltage
# Feature [AP_amplitude] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_amplitude_from_voltagebase:
# Voltage never goes below or above threshold in spike detection.
#
# Feature [peak_voltage] is missing
# Error calculating peak_voltage for AP_amplitude_from_voltagebase
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_begin_voltage:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_begin_width:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [min_AHP_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_duration:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_duration_change:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
# Feature [AP_duration] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_duration_half_width:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
# Feature [AP_rise_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_duration_half_width_change:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
# Feature [AP_rise_indices] is missing
#
# Feature [AP_duration_half_width] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_height:
# Voltage never goes below or above threshold in spike detection.
#
# Feature [peak_voltage] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_rise_rate:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_rise_rate_change:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
# Feature [AP_rise_rate] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_rise_time:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature AP_width:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# No spike in trace.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature ISI_values:
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature amp_drop_first_last:
# Voltage never goes below or above threshold in spike detection.
#
# Feature [peak_voltage] is missing
# At least 2 spikes needed for calculation of amp_drop_first_last.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature amp_drop_first_second:
# Voltage never goes below or above threshold in spike detection.
#
# Feature [peak_voltage] is missing
# At least 2 spikes needed for calculation of amp_drop_first_second.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature amp_drop_second_last:
# Voltage never goes below or above threshold in spike detection.
#
# Feature [peak_voltage] is missing
# At least 3 spikes needed for calculation of amp_drop_second_last.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature doublet_ISI:
# Voltage never goes below or above threshold in spike detection.
#
# Need at least two spikes for doublet_ISI.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature fast_AHP:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
# Feature [AP_begin_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature irregularity_index:
# Voltage never goes below or above threshold in spike detection.
#
#  Three spikes required for calculation of ISI_values.
#
# Feature [ISI_values] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature max_amp_difference:
# Voltage never goes below or above threshold in spike detection.
#
# Feature [peak_voltage] is missing
# At least 2 spikes needed for calculation of max_amp_difference.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature mean_frequency:
# Voltage never goes below or above threshold in spike detection.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature min_AHP_values:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature peak_voltage:
# Voltage never goes below or above threshold in spike detection.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature spike_half_width:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature spike_width2:
# Voltage never goes below or above threshold in spike detection.
#
#  At least one spike required for calculation of min_AHP_indices.
#
# Feature [min_AHP_indices] is missing
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature time_to_first_spike:
# Voltage never goes below or above threshold in spike detection.
#
#  One spike required for time_to_first_spike.
#
#   RuntimeWarning)
# /home/saray/venv_Python3/lib/python3.5/site-packages/efel/api.py:480: RuntimeWarning: Error while calculating feature time_to_second_spike:
# Voltage never goes below or above threshold in spike detection.
#
#  Two spikes required for time_to_second_spike.
#
#   RuntimeWarning)
# The figures are saved in the directory:  ../published_models_validation_results/figs/somaticfeat_JMakara_data/Golding_2001_weak_prop_fig9B/
# Features excluded (due to invalid values): AHP1_depth_from_peak.Step0.15, AHP2_depth_from_peak.Step0.15, AHP_depth.Step0.15, AHP_depth_abs.Step0.15, AHP_depth_diff.Step0.15, AHP_depth_from_peak.Step0.15, AHP_time_from_peak.Step0.15, AP1_peak.Step0.15, AP2_AP1_peak_diff.Step0.15, AP2_amp.Step0.15, AP2_begin_voltage.Step0.15, AP2_begin_width.Step0.15, AP2_peak.Step0.15, AP2_width.Step0.15, AP_amplitude.Step0.15, AP_amplitude_change.Step0.15, AP_amplitude_from_voltagebase.Step0.15, AP_begin_voltage.Step0.15, AP_begin_width.Step0.15, AP_duration.Step0.15, AP_duration_change.Step0.15, AP_duration_half_width.Step0.15, AP_duration_half_width_change.Step0.15, AP_fall_rate.Step0.15, AP_fall_time.Step0.15, AP_height.Step0.15, AP_rise_rate.Step0.15, AP_rise_rate_change.Step0.15, AP_rise_time.Step0.15, AP_width.Step0.15, APlast_amp.Step0.15, ISI_values.Step0.15, amp_drop_first_last.Step0.15, amp_drop_first_second.Step0.15, amp_drop_second_last.Step0.15, doublet_ISI.Step0.15, fast_AHP.Step0.15, irregularity_index.Step0.15, max_amp_difference.Step0.15, mean_frequency.Step0.15, min_AHP_values.Step0.15, min_voltage_between_spikes.Step0.15, peak_voltage.Step0.15, spike_half_width.Step0.15, spike_width2.Step0.15, time_to_first_spike.Step0.15, time_to_second_spike.Step0.15
# Number of features succesfully evaluated: 258/305
# Results are saved in the directory:  ../published_models_validation_results/results/somaticfeat_JMakara_data/Golding_2001_weak_prop_fig9B/
# === Model Golding_2001_weak_prop_fig9B achieved score ZScore_avg = 4.65 on test 'Somatic features test'. ===

# %% [markdown]
# ### PSP Attenuatuion Test
#
# The PSP Attenuation Test evaluates how much the post synaptic potential (using EPSC stimulus) attenuates from the main apical dendrite (different distances) to the soma. The soma/dendrite attenuation is compared to data from Magee & Cook 2000 (http://dx.doi.org/10.1038/78800).

# %%
# Load target data
with open("../target_features/feat_PSP_attenuation_target_data.json", 'r') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_attenuation_soma/dend_100_um</th><td>0.67037891837</td></tr><tr><th>std_attenuation_soma/dend_100_um</th><td>0.0745536001493</td></tr><tr><th>mean_attenuation_soma/dend_200_um</th><td>0.485024302539</td></tr><tr><th>std_attenuation_soma/dend_200_um</th><td>0.108372269307</td></tr><tr><th>mean_attenuation_soma/dend_300_um</th><td>0.282118043034</td></tr><tr><th>std_attenuation_soma/dend_300_um</th><td>0.0482703550105</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/PSP_attenuation_stim/stim_PSP_attenuation_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate test class 
test = tests.PSPAttenuationTest(config=config, observation=observation, num_of_dend_locations = 15, force_run=False, show_plot=True, save_all = True, base_directory=base_directory)
            
# Number of parallel processes
test.npool = 10

try: 
    # Run the test 
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('dendA5_01', 0.8636363636363638): 77.09033393311545, ('dendA5_01', 0.40909090909090906): 50.976019794540925, ('dendA5_01111111111111', 0.045454545454545456): 283.447816389045, ('dendA5_0111111111111', 0.21428571428571427): 254.78367321852483, ('dendA5_011111111111', 0.5): 239.79096715191383, ('dendA5_0111111111111', 0.9285714285714284): 278.8585387217133, ('dendA5_01111111111111', 0.6818181818181819): 313.99289202722485, ('dendA5_0111111111111', 0.3571428571428571): 259.5986463191625, ('dendA5_011', 0.8999999999999999): 103.9835181978471, ('dendA5_01111111111111', 0.9545454545454547): 327.083638729302, ('dendA5_01111111111111', 0.13636363636363635): 287.8113986230707, ('dendA5_0111111111111', 0.07142857142857142): 249.96870011788712, ('dendA5_01111', 0.9285714285714284): 142.45692935032375, ('dendA5_011', 0.30000000000000004): 91.2775915157409, ('dendA5_0111111111', 0.5): 213.20068049562843}
# input at: dendA5_01(0.8636363636363638) with weight: 0.0
# input at: dendA5_0111111111111(0.9285714285714284) with weight: 0.0
# input at: dendA5_0111111111111(0.07142857142857142) with weight: 0.0
# input at: dendA5_011111111111(0.5) with weight: 0.0
# input at: dendA5_0111111111111(0.21428571428571427) with weight: 0.0
# input at: dendA5_0111111111111(0.3571428571428571) with weight: 0.0
# input at: dendA5_01(0.40909090909090906) with weight: 0.0
# input at: dendA5_01111111111111(0.6818181818181819) with weight: 0.0
# input at: dendA5_01111(0.9285714285714284) with weight: 0.0
# input at: dendA5_01111111111111(0.045454545454545456) with weight: 0.0
# input at: dendA5_01111111111111(0.9545454545454547) with weight: 0.0
# input at: dendA5_011(0.8999999999999999) with weight: 0.0
# input at: dendA5_01111111111111(0.13636363636363635) with weight: 0.0
# input at: dendA5_011(0.30000000000000004) with weight: 0.0
# input at: dendA5_0111111111(0.5) with weight: 0.0
# input at: dendA5_0111111111111(0.21428571428571427) with weight: 0.000405541155148789
# input at: dendA5_01(0.8636363636363638) with weight: 0.0004084646172876187
# input at: dendA5_01111111111111(0.6818181818181819) with weight: 0.00040488917424081684
# input at: dendA5_01(0.40909090909090906) with weight: 0.00040882643616073025
# input at: dendA5_011111111111(0.5) with weight: 0.0004057023888094875
# input at: dendA5_0111111111111(0.9285714285714284) with weight: 0.0004052785241589194
# input at: dendA5_011(0.30000000000000004) with weight: 0.00040826493573640094
# input at: dendA5_01111111111111(0.045454545454545456) with weight: 0.00040522271555411266
# input at: dendA5_01111111111111(0.9545454545454547) with weight: 0.0004047791574823582
# input at: dendA5_0111111111111(0.3571428571428571) with weight: 0.0004054931928957257
# input at: dendA5_01111111111111(0.13636363636363635) with weight: 0.00040517313432536755
# input at: dendA5_0111111111111(0.07142857142857142) with weight: 0.0004055896030272828
# input at: dendA5_01111(0.9285714285714284) with weight: 0.0004073032547671601
# input at: dendA5_011(0.8999999999999999) with weight: 0.0004080767383520952
# input at: dendA5_0111111111(0.5) with weight: 0.00040601198846261185
# The figures are saved in the directory:  ../published_models_validation_results/figs/PSP_attenuation/Golding_2001_weak_prop_fig9B/
# === Model Golding_2001_weak_prop_fig9B achieved score ZScore_avg = 0.95 on test 'PSP attenuation test'. ===

# %% [markdown]
# ### Back-Propagating AP Test
#
# The Back-Propagating AP Test evaluates the mode and efficacy of back-propagating action potentials on the apical trunk in locations of different distances from the soma. The amplitude of the first and last AP of around 15 Hz train is compared to experimental data from Golding et al. 2001 (https://doi.org/10.1152/jn.2001.86.6.2998).

# %%
# Load target data
with open('../target_features/feat_backpropagating_AP_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

#observation = config['features']
IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_AP1_amp_at_50um</th><td>66.6474010216 mV</td></tr><tr><th>std_AP1_amp_at_50um</th><td>7.6800611053 mV</td></tr><tr><th>mean_AP1_amp_at_150um</th><td>61.6405452338 mV</td></tr><tr><th>std_AP1_amp_at_150um</th><td>8.84061901299 mV</td></tr><tr><th>mean_AP1_amp_at_250um</th><td>57.1478276286 mV</td></tr><tr><th>std_AP1_amp_at_250um</th><td>6.74288151869 mV</td></tr><tr><th>mean_AP1_amp_strong_propagating_at_350um</th><td>52.5065653152 mV</td></tr><tr><th>std_AP1_amp_strong_propagating_at_350um</th><td>5.82443856294 mV</td></tr><tr><th>mean_AP1_amp_weak_propagating_at_350um</th><td>18.7832282514 mV</td></tr><tr><th>std_AP1_amp_weak_propagating_at_350um</th><td>1.87203344953 mV</td></tr><tr><th>mean_APlast_amp_at_50um</th><td>56.0027067193 mV</td></tr><tr><th>std_APlast_amp_at_50um</th><td>6.66451614848 mV</td></tr><tr><th>mean_APlast_amp_at_150um</th><td>41.6724147741 mV</td></tr><tr><th>std_APlast_amp_at_150um</th><td>7.62175409041 mV</td></tr><tr><th>mean_APlast_amp_at_250um</th><td>21.1507839635 mV</td></tr><tr><th>std_APlast_amp_at_250um</th><td>2.39551093081 mV</td></tr><tr><th>mean_APlast_amp_at_350um</th><td>9.81008709754 mV</td></tr><tr><th>std_APlast_amp_at_350um</th><td>3.67378280696 mV</td></tr></table>

# %%
# Load stimuli file
stim_file = pkg_resources.resource_filename("hippounit", "tests/stimuli/bAP_stim/stim_bAP_test.json")

with open(stim_file, 'r') as f:
    config = json.load(f, object_pairs_hook=collections.OrderedDict)

# Instantiate the test class
test = tests.BackpropagatingAPTest(config=config, observation=observation, force_run=False, force_run_FindCurrentStim=False, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# Dendritic locations to be tested (with their actual distances): {('dendA5_01', 0.13636363636363635): 35.307431311396215, ('dendA5_01', 0.3181818181818182): 45.75315696682602, ('dendA5_011111', 0.5): 150.49165189616144, ('dendA5_011111111111111', 0.8333333333333333): 337.0317515174673, ('dendA5_011111', 0.8333333333333333): 154.36548396187922, ('dendA5_01', 0.40909090909090906): 50.976019794540925, ('dendA5_0111111111111111', 0.14705882352941174): 350.10695618339867, ('dendA5_0111111', 0.07142857142857142): 158.71368187315855, ('dendA5_0111111111111111', 0.029411764705882353): 340.88940391803794, ('dendA5_0111111111111111', 0.2647058823529412): 359.3245084487594, ('dendA5_01111111111', 0.8333333333333333): 230.5970310460218, ('dendA5_01', 0.6818181818181819): 66.64460827768563, ('dendA5_0111111111111111', 0.20588235294117646): 354.715732316079, ('dendA5_01111', 0.7857142857142856): 138.0089804558018, ('dendA5_0111111', 0.21428571428571427): 163.53624562999937, ('dendA5_01', 0.045454545454545456): 30.084568483681313, ('dendA5_011111111111111', 0.16666666666666666): 330.8186941805453, ('dendA5_0111111111111111', 0.3823529411764706): 368.5420607141201, ('dendA5_0111111', 0.3571428571428571): 168.35880938684022, ('dendA5_01', 0.22727272727272727): 40.53029413911112, ('dendA5_01', 0.5): 56.19888262225582, ('dendA5_0111111111111', 0.21428571428571427): 254.78367321852483, ('dendA5_0111111111111', 0.3571428571428571): 259.5986463191625, ('dendA5_011111111111', 0.8333333333333333): 244.9711314290168, ('dendA5_0111111111111', 0.6428571428571428): 269.2285925204379, ('dendA5_01111', 0.6428571428571428): 133.56103156127986, ('dendA5_0111111111111111', 0.3235294117647059): 363.93328458143975, ('dendA5_0111111111111', 0.49999999999999994): 264.4136194198002, ('dendA5_011111111111111', 0.5): 333.9252228490063, ('dendA5_011111', 0.16666666666666666): 146.61781983044364, ('dendA5_01111', 0.9285714285714284): 142.45692935032375, ('dendA5_0111111111111', 0.07142857142857142): 249.96870011788712, ('dendA5_0111111111111111', 0.08823529411764705): 345.4981800507183, ('dendA5_011111111111', 0.16666666666666666): 234.61080287481082, ('dendA5_01', 0.5909090909090909): 61.42174544997073, ('dendA5_011111111111', 0.5): 239.79096715191383}
# Finding appropriate current step amplitude...
# - running amplitude: 0.4 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.5 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.6000000000000001 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.8 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.9 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.7000000000000001 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.1 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.0 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.30000000000000004 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.2 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.0 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.13999999999999999 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.16999999999999998 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.17999999999999997 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.14500000000000005 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.17000000000000007 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.18500000000000008 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.17500000000000007 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.18000000000000008 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.14750000000000005 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.17250000000000007 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.17750000000000007 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# WARNING: No current amplitude value has been found to which the model's firing frequency is between 10 and 20 Hz. The simulation is done using the current amplitude value to which the models fires at a frequency nearest to 15 Hz, but not 0 Hz. Current step amplitude: 0.17750000000000007nA, frequency: [25]Hz
#
# - running amplitude: 0.17750000000000007 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/backpropagating_AP/Golding_2001_weak_prop_fig9B/
# This is a rather WEAK propagating model
# === Model Golding_2001_weak_prop_fig9B achieved score Z_score_avg_WEAK_propagating = 2.56 on test 'Back-propagating action potential test'. ===

# %% [markdown]
# ### Depolarization-block Test
#
# The Depolarization Block Test aims to determine whether the model enters depolarization block to prolonged, high intensity somatic current stimulus. It compares the current intensity to which the model fires the maximum number of action potentials, the current intensity before the model enters depolarization block (the two should be equal) and the equilibrium potential during depolarization block to the experimental data of Bianchi et al. 2012 (http://dx.doi.org/10.1007/s10827-012-0383-y).

# %%
# Load target data
with open('../target_features/depol_block_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

#observation = config['features']
IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_Ith</th><td>0.6 nA</td></tr><tr><th>Ith_std</th><td>0.3 nA</td></tr><tr><th>mean_Veq</th><td>-40.1 mV</td></tr><tr><th>Veq_std</th><td>3.4 mV</td></tr></table>

# %%
# Instantiate the test class

test = tests.DepolarizationBlockTest(observation=observation, force_run=False, show_plot=True, save_all=True, base_directory=base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# - running amplitude: 0.35000000000000003 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.1 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.0 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.15000000000000002 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.2 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.05 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.45 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.30000000000000004 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.25 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.4 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.5 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.55 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.6000000000000001 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.65 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.7000000000000001 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.75 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.8 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.8500000000000001 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.9 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 0.9500000000000001 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.0 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.05 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.1 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.1500000000000001 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.2000000000000002 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.25 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.3 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.35 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.4000000000000001 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.4500000000000002 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.5 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.55 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# - running amplitude: 1.6 on model: Golding_2001_weak_prop_fig9B at: somaA(0.5)
# The figures are saved in the directory:  ../published_models_validation_results/figs/depol_block/Golding_2001_weak_prop_fig9B/
# I_maxNumAP (the current intensity for which the model exhibited the maximum number of APs): 1.35 nA
# I_below_depol_block (the current intensity before the model enters depolarization block): 1.4000000000000001 nA
# Veq (the equilibrium value during the depolarization block): -34.03847747694751 mV
# Results are saved in the directory:  ../published_models_validation_results/results/depol_block/Golding_2001_weak_prop_fig9B/
# According to the experiment I_maxNumAP and I_below_depol_block should be equal. If they are not equal a penalty is applied (200 * the difference between them in nA).
# === Model Golding_2001_weak_prop_fig9B achieved score ZScore_avg+penalty = 12.32 on test 'Depolarization block test'. ===

# %% [markdown]
# ### Oblique Integration Test
#
# Tests signal integration in oblique dendrites for increasing number of synchronous and asynchronous synaptic inputs. The experimental data is obtained from Losonczy and Magee 2006 (https://doi.org/10.1016/j.neuron.2006.03.016).

# %%
# Load target data
with open('../target_features/oblique_target_data.json') as f:
    observation = json.load(f, object_pairs_hook=collections.OrderedDict)

IPython.display.HTML(json2html.convert(json = observation))
# Out:
# <table border="1"><tr><th>mean_threshold</th><td>3.4 mV</td></tr><tr><th>threshold_sem</th><td>0.2 mV</td></tr><tr><th>exp_n</th><td>92</td></tr><tr><th>mean_prox_threshold</th><td>4.5 mV</td></tr><tr><th>prox_threshold_sem</th><td>0.5 mV</td></tr><tr><th>prox_n</th><td>33</td></tr><tr><th>mean_dist_threshold</th><td>2.6 mV</td></tr><tr><th>dist_threshold_sem</th><td>0.2 mV</td></tr><tr><th>dist_n</th><td>44</td></tr><tr><th>mean_nonlin_at_th</th><td>142</td></tr><tr><th>nonlin_at_th_sem</th><td>9</td></tr><tr><th>mean_nonlin_suprath</th><td>129.0</td></tr><tr><th>nonlin_suprath_sem</th><td>6.0</td></tr><tr><th>mean_peak_deriv</th><td>2.6 V/s</td></tr><tr><th>peak_deriv_sem</th><td>0.4 V/s</td></tr><tr><th>mean_amp_at_th</th><td>4.828 mV</td></tr><tr><th>amp_at_th_sem</th><td>0.28 mV</td></tr><tr><th>mean_time_to_peak</th><td>13.5 ms</td></tr><tr><th>time_to_peak_sem</th><td>0.2 ms</td></tr><tr><th>mean_async_nonlin</th><td>104.0</td></tr><tr><th>async_nonlin_sem</th><td>8.0</td></tr><tr><th>async_n</th><td>23</td></tr></table>

# %%
# Instantiate the test class
test = tests.ObliqueIntegrationTest(observation = observation, save_all = True, force_run_synapse=False, force_run_bin_search=False, show_plot = True, base_directory = base_directory)

# Number of parallel processes
test.npool = 10

try: 
    # Run the test
    score = test.judge(model)
    #Summarize and print the score achieved by the model on the test using SciUnit's summarize function
    score.summarize()
except Exception as e:
    print('Model: ' + model.name + ' could not be run')
    print(e)
    pass
# Out:
# Dendrites and locations to be tested:  [['dendA5_00', 0.22499999999999998, 'prox'], ['dendA5_00', 0.625, 'dist'], ['dendA5_0101', 0.6428571428571428, 'prox'], ['dendA5_0101', 0.9, 'dist'], ['dendA5_0100', 0.7, 'prox'], ['dendA5_0100', 0.9, 'dist'], ['dendA5_01110', 0.875, 'prox'], ['dendA5_01110', 0.9, 'dist'], ['dendA5_01100', 0.1956521739130435, 'prox'], ['dendA5_01100', 0.4565217391304347, 'dist'], ['dendA5_011010', 0.875, 'prox'], ['dendA5_011010', 0.9, 'dist'], ['dendA5_0110111', 0.35, 'prox'], ['dendA5_0110111', 0.8499999999999999, 'dist'], ['dendA5_0110110', 0.6428571428571428, 'prox'], ['dendA5_0110110', 0.9, 'dist']]
#
# The built in Exp2Syn is used as the AMPA component. Tau1 = 0.1 ,Tau2 = 2.0 .
#
#
# The default NMDA model of HippoUnit is used with Jahr, Stevens voltage dependence.
#
# Adjusting synaptic weights on all the locations ...
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.22499999999999998
# - number of inputs: 0 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 1 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 2 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 3 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 4 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 5 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 6 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 7 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 8 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 9 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 10 dendrite: dendA5_00 xloc: 0.625
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.6428571428571428
# - number of inputs: 0 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0101 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.7
# - number of inputs: 0 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0100 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.875
# - number of inputs: 0 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_01110 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.1956521739130435
# - number of inputs: 0 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 1 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 2 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 3 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 4 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 5 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 6 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 7 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 8 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 9 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 10 dendrite: dendA5_01100 xloc: 0.4565217391304347
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.875
# - number of inputs: 0 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_011010 xloc: 0.9
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.35
# - number of inputs: 0 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 1 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 2 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 3 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 4 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 5 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 6 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 7 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 8 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 9 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 10 dendrite: dendA5_0110111 xloc: 0.8499999999999999
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.6428571428571428
# - number of inputs: 0 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 1 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 2 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 3 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 4 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 5 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 6 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 7 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 8 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 9 dendrite: dendA5_0110110 xloc: 0.9
# - number of inputs: 10 dendrite: dendA5_0110110 xloc: 0.9
# The figures are saved in the directory:  ../published_models_validation_results/figs/oblique_integration/Golding_2001_weak_prop_fig9B/
# Results are saved in the directory:  ../published_models_validation_results/results/oblique_integration/Golding_2001_weak_prop_fig9B/
# === Model Golding_2001_weak_prop_fig9B achieved score ZScore_avg = 1.14 on test 'Oblique integration test'. ===

# %%
# %load_ext watermark

# %%
# %watermark -v -m -p sciunit,efel,numpy,quantities,scipy,matplotlib,neuron
# Out:
# CPython 3.5.2
# IPython 5.6.0
#
# sciunit 0.2.1.1
# efel 3.0.58
# numpy 1.16.4
# quantities 0.12.1
# scipy 1.3.0
# matplotlib 3.0.3
# neuron 7.6.2
#
# compiler   : GCC 5.4.0 20160609
# system     : Linux
# release    : 4.15.0-60-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 56
# interpreter: 64bit
